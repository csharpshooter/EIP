# %% [markdown]
# <a href="https://colab.research.google.com/github/csharpshooter/EIP/blob/master/A5/Assignment5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# mount gdrive and unzip data
from google.colab import drive
drive.mount('/content/gdrive')
# !unzip -q "/content/gdrive/My Drive/EIP/Assignment5Dataset/hvc_data.zip"
# look for `hvc_annotations.csv` file and `resized` dir
# %ls
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# gdrive/  hvc_annotations.csv  resized/  sample_data/

# %%
# %tensorflow_version 1.x

import cv2
import json

import numpy as np
import pandas as pd

from functools import partial
from pathlib import Path 
from tqdm import tqdm

from google.colab.patches import cv2_imshow

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder


from keras.applications import VGG16,VGG19
from keras.layers.core import Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.layers import Input, AveragePooling2D, GlobalAveragePooling2D
from keras.models import Model
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping
from keras.callbacks import ReduceLROnPlateau

# %%
# load annotations
df = pd.read_csv("hvc_annotations.csv")
del df["filename"] # remove unwanted column
df.head()
# Out:
#    gender imagequality    age  ...        emotion        bodypose     image_path
# 0    male      Average  35-45  ...        Neutral  Front-Frontish  resized/1.jpg
# 1  female      Average  35-45  ...  Angry/Serious  Front-Frontish  resized/2.jpg
# 2    male         Good  45-55  ...        Neutral  Front-Frontish  resized/3.jpg
# 3    male         Good  45-55  ...        Neutral  Front-Frontish  resized/4.jpg
# 4  female         Good  35-45  ...        Neutral  Front-Frontish  resized/5.jpg
#
# [5 rows x 9 columns]

# %%
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
# print('Using real-time data augmentation.')  
# This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        # featurewise_center=True,
        # set each sample mean to 0
        # samplewise_center=True,
        # divide inputs by std of dataset
        # featurewise_std_normalization=True,
        # divide each input by its std
        # samplewise_std_normalization=True,
        # apply ZCA whitening
        # zca_whitening=False,
        # epsilon for ZCA whitening
        # zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        # rotation_range=90,
        # randomly shift images horizontally
        # width_shift_range=0.1,
        # randomly shift images vertically
        # height_shift_range=0.1,
        # set range for random shear
        # shear_range=0.,
        # set range for random zoom
        # zoom_range=0.,
        # set range for random channel shifts
        # channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        # fill_mode='nearest',
        # value used for fill_mode = "constant"
        # cval=0.,
        # randomly flip images
        # horizontal_flip=True,
        # randomly flip images
        # vertical_flip=True,
        # set rescaling factor (applied before any other transformation)
        # rescale=None,
        # set function that will be applied on each input
        preprocessing_function=get_random_eraser(v_l=0, v_h=1, pixel_level=False),
        # image data format, either "channels_first" or "channels_last"
        #data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        #validation_split=0.15
        )

# %%
# one hot encoding of labels

one_hot_df = pd.concat([
    df[["image_path"]],
    pd.get_dummies(df.gender, prefix="gender"),
    pd.get_dummies(df.imagequality, prefix="imagequality"),
    pd.get_dummies(df.age, prefix="age"),
    pd.get_dummies(df.weight, prefix="weight"),
    pd.get_dummies(df.carryingbag, prefix="carryingbag"),  
    pd.get_dummies(df.footwear, prefix="footwear"),
    pd.get_dummies(df.emotion, prefix="emotion"),
    pd.get_dummies(df.bodypose, prefix="bodypose"),
], axis = 1)

one_hot_df.head().T
# Out:
#                                                   0  ...              4
# image_path                            resized/1.jpg  ...  resized/5.jpg
# gender_female                                     0  ...              1
# gender_male                                       1  ...              0
# imagequality_Average                              1  ...              0
# imagequality_Bad                                  0  ...              0
# imagequality_Good                                 0  ...              1
# age_15-25                                         0  ...              0
# age_25-35                                         0  ...              0
# age_35-45                                         1  ...              1
# age_45-55                                         0  ...              0
# age_55+                                           0  ...              0
# weight_normal-healthy                             1  ...              0
# weight_over-weight                                0  ...              0
# weight_slightly-overweight                        0  ...              1
# weight_underweight                                0  ...              0
# carryingbag_Daily/Office/Work Bag                 0  ...              0
# carryingbag_Grocery/Home/Plastic Bag              1  ...              0
# carryingbag_None                                  0  ...              1
# footwear_CantSee                                  0  ...              1
# footwear_Fancy                                    0  ...              0
# footwear_Normal                                   1  ...              0
# emotion_Angry/Serious                             0  ...              0
# emotion_Happy                                     0  ...              0
# emotion_Neutral                                   1  ...              1
# emotion_Sad                                       0  ...              0
# bodypose_Back                                     0  ...              0
# bodypose_Front-Frontish                           1  ...              1
# bodypose_Side                                     0  ...              0
#
# [28 rows x 5 columns]

# %%
import keras
import numpy as np

# Label columns per attribute
_gender_cols_ = [col for col in one_hot_df.columns if col.startswith("gender")]
_imagequality_cols_ = [col for col in one_hot_df.columns if col.startswith("imagequality")]
_age_cols_ = [col for col in one_hot_df.columns if col.startswith("age")]
_weight_cols_ = [col for col in one_hot_df.columns if col.startswith("weight")]
_carryingbag_cols_ = [col for col in one_hot_df.columns if col.startswith("carryingbag")]
_footwear_cols_ = [col for col in one_hot_df.columns if col.startswith("footwear")]
_emotion_cols_ = [col for col in one_hot_df.columns if col.startswith("emotion")]
_bodypose_cols_ = [col for col in one_hot_df.columns if col.startswith("bodypose")]

class PersonDataGenerator(keras.utils.Sequence):
    """Ground truth data generator"""

    
    def __init__(self, df, batch_size=32, shuffle=True, augmentation=None):
        self.df = df
        self.batch_size=batch_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.augmentation = augmentation

    def __len__(self):
        return int(np.floor(self.df.shape[0] / self.batch_size))

    def __getitem__(self, index):
        """fetch batched images and targets"""
        batch_slice = slice(index * self.batch_size, (index + 1) * self.batch_size)
        items = self.df.iloc[batch_slice]
        image = np.stack([cv2.imread(item["image_path"]) for _, item in items.iterrows()])

        if self.augmentation is not None:
          self.augmentation.fit(image)
          image = self.augmentation.flow(image,shuffle=False).next()

        target = {
            "gender_output": items[_gender_cols_].values,
            "image_quality_output": items[_imagequality_cols_].values,
            "age_output": items[_age_cols_].values,
            "weight_output": items[_weight_cols_].values,
            "bag_output": items[_carryingbag_cols_].values,
            "pose_output": items[_bodypose_cols_].values,
            "footwear_output": items[_footwear_cols_].values,
            "emotion_output": items[_emotion_cols_].values,
        }

        return image, target

    def on_epoch_end(self):
        """Updates indexes after each epoch"""
        if self.shuffle == True:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

# %%
from sklearn.model_selection import train_test_split
train_df, val_df = train_test_split(one_hot_df, test_size=0.15)
train_df.shape, val_df.shape
# Out:
# ((11537, 28), (2036, 28))

# %%
train_df.head()
# Out:
#               image_path  gender_female  ...  bodypose_Front-Frontish  bodypose_Side
# 1331    resized/1332.jpg              0  ...                        0              1
# 10346  resized/10348.jpg              1  ...                        1              0
# 6434    resized/6435.jpg              1  ...                        1              0
# 2512    resized/2513.jpg              0  ...                        0              1
# 9324    resized/9325.jpg              0  ...                        1              0
#
# [5 rows x 28 columns]

# %%
# create train and validation data generators
train_gen = PersonDataGenerator(train_df, batch_size=32, shuffle=False, augmentation=datagen)
valid_gen = PersonDataGenerator(val_df, batch_size=32, shuffle=False, augmentation=None)

# %%
# get number of output units from data
images, targets = next(iter(train_gen))
num_units = { k.split("_output")[0]:v.shape[1] for k, v in targets.items()}
num_units
# Out:
# {'age': 5,
#  'bag': 3,
#  'emotion': 4,
#  'footwear': 3,
#  'gender': 2,
#  'image_quality': 3,
#  'pose': 3,
#  'weight': 4}

# %%
backbone = VGG16(
    weights=None, 
    include_top=False, 
    input_tensor=Input(shape=(224, 224, 3))
)

neck = backbone.output
neck = Flatten(name="flatten")(neck)
neck = Dense(512, activation="relu")(neck)


def build_tower(in_layer):
    neck = Dropout(0.2)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    neck = Dropout(0.3)(neck)
    neck = Dense(128, activation="relu")(neck)
    return neck


def build_tower_emotion(in_layer):
    neck = Dropout(0.4)(in_layer)
    neck = Dense(256, activation="relu")(neck)
    neck = Dropout(0.4)(neck)
    neck = Dense(256, activation="relu")(neck)
    return neck

def build_head(name, in_layer):
    return Dense(
        num_units[name], activation="softmax", name=f"{name}_output"
    )(in_layer)

# heads
gender = build_head("gender", build_tower(neck))
image_quality = build_head("image_quality", build_tower(neck))
age = build_head("age", build_tower(neck))
weight = build_head("weight", build_tower(neck))
bag = build_head("bag", build_tower(neck))
footwear = build_head("footwear", build_tower(neck))
emotion = build_head("emotion", build_tower_emotion(neck))
pose = build_head("pose", build_tower(neck))


model = Model(
    inputs=backbone.input, 
    outputs=[gender, image_quality, age, weight, bag, footwear, pose, emotion]
)

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 45:
        lr *= 0.5e-3
    elif epoch > 35:
        lr *= 1e-3
    elif epoch > 25:
        lr *= 1e-2
    elif epoch > 15:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

    # lr = 0.5
    # if epoch > 45:
    #     lr *= 0.1
    # elif epoch > 40:
    #     lr *= 0.2
    # elif epoch > 30:
    #     lr *= 0.3
    # elif epoch > 20:
    #     lr *= 0.4
    # print('Learning rate: ', lr)
    # return lr

# %%
losses = {
 	"gender_output": "binary_crossentropy",
 	"image_quality_output": "categorical_crossentropy",
 	"age_output": "categorical_crossentropy",
 	"weight_output": "categorical_crossentropy",
  "bag_output": "categorical_crossentropy",
 	"footwear_output": "categorical_crossentropy",
 	"pose_output": "categorical_crossentropy",
  "emotion_output": "categorical_crossentropy",
 }

loss_weights = {"gender_output": 1.0, "image_quality_output": 1.0, "age_output": 1.5,"weight_output": 1.0,"bag_output": 1.0,"footwear_output": 1.0,"pose_output": 1.0,"emotion_output": 1.0}

opt = SGD(lr=0.001, momentum=0.9)
model.compile(
    optimizer=opt,
    loss=losses, 
    loss_weights=loss_weights, 
    metrics=["accuracy"]
)

# %%
# model.fit(X_train, y_train, validation_data=(X_valid, y_valid), batch_size=32, epochs=10)
model.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 224, 224, 64) 1792        input_4[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 224, 224, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 112, 112, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 112, 112, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 112, 112, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 56, 56, 128)  0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 56, 56, 256)  295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 56, 56, 256)  590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 56, 56, 256)  590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 28, 28, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 28, 28, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 28, 28, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 28, 28, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 14, 14, 512)  0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 14, 14, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 14, 14, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 14, 14, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 7, 7, 512)    0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 25088)        0           block5_pool[0][0]
# __________________________________________________________________________________________________
# dense_52 (Dense)                (None, 512)          12845568    flatten[0][0]
# __________________________________________________________________________________________________
# dropout_49 (Dropout)            (None, 512)          0           dense_52[0][0]
# __________________________________________________________________________________________________
# dropout_51 (Dropout)            (None, 512)          0           dense_52[0][0]
# __________________________________________________________________________________________________
# dropout_53 (Dropout)            (None, 512)          0           dense_52[0][0]
# __________________________________________________________________________________________________
# dropout_55 (Dropout)            (None, 512)          0           dense_52[0][0]
# __________________________________________________________________________________________________
# dropout_57 (Dropout)            (None, 512)          0           dense_52[0][0]
# __________________________________________________________________________________________________
# dropout_59 (Dropout)            (None, 512)          0           dense_52[0][0]
# __________________________________________________________________________________________________
# dropout_63 (Dropout)            (None, 512)          0           dense_52[0][0]
# __________________________________________________________________________________________________
# dropout_61 (Dropout)            (None, 512)          0           dense_52[0][0]
# __________________________________________________________________________________________________
# dense_53 (Dense)                (None, 128)          65664       dropout_49[0][0]
# __________________________________________________________________________________________________
# dense_55 (Dense)                (None, 128)          65664       dropout_51[0][0]
# __________________________________________________________________________________________________
# dense_57 (Dense)                (None, 128)          65664       dropout_53[0][0]
# __________________________________________________________________________________________________
# dense_59 (Dense)                (None, 128)          65664       dropout_55[0][0]
# __________________________________________________________________________________________________
# dense_61 (Dense)                (None, 128)          65664       dropout_57[0][0]
# __________________________________________________________________________________________________
# dense_63 (Dense)                (None, 128)          65664       dropout_59[0][0]
# __________________________________________________________________________________________________
# dense_67 (Dense)                (None, 128)          65664       dropout_63[0][0]
# __________________________________________________________________________________________________
# dense_65 (Dense)                (None, 256)          131328      dropout_61[0][0]
# __________________________________________________________________________________________________
# dropout_50 (Dropout)            (None, 128)          0           dense_53[0][0]
# __________________________________________________________________________________________________
# dropout_52 (Dropout)            (None, 128)          0           dense_55[0][0]
# __________________________________________________________________________________________________
# dropout_54 (Dropout)            (None, 128)          0           dense_57[0][0]
# __________________________________________________________________________________________________
# dropout_56 (Dropout)            (None, 128)          0           dense_59[0][0]
# __________________________________________________________________________________________________
# dropout_58 (Dropout)            (None, 128)          0           dense_61[0][0]
# __________________________________________________________________________________________________
# dropout_60 (Dropout)            (None, 128)          0           dense_63[0][0]
# __________________________________________________________________________________________________
# dropout_64 (Dropout)            (None, 128)          0           dense_67[0][0]
# __________________________________________________________________________________________________
# dropout_62 (Dropout)            (None, 256)          0           dense_65[0][0]
# __________________________________________________________________________________________________
# dense_54 (Dense)                (None, 128)          16512       dropout_50[0][0]
# __________________________________________________________________________________________________
# dense_56 (Dense)                (None, 128)          16512       dropout_52[0][0]
# __________________________________________________________________________________________________
# dense_58 (Dense)                (None, 128)          16512       dropout_54[0][0]
# __________________________________________________________________________________________________
# dense_60 (Dense)                (None, 128)          16512       dropout_56[0][0]
# __________________________________________________________________________________________________
# dense_62 (Dense)                (None, 128)          16512       dropout_58[0][0]
# __________________________________________________________________________________________________
# dense_64 (Dense)                (None, 128)          16512       dropout_60[0][0]
# __________________________________________________________________________________________________
# dense_68 (Dense)                (None, 128)          16512       dropout_64[0][0]
# __________________________________________________________________________________________________
# dense_66 (Dense)                (None, 256)          65792       dropout_62[0][0]
# __________________________________________________________________________________________________
# gender_output (Dense)           (None, 2)            258         dense_54[0][0]
# __________________________________________________________________________________________________
# image_quality_output (Dense)    (None, 3)            387         dense_56[0][0]
# __________________________________________________________________________________________________
# age_output (Dense)              (None, 5)            645         dense_58[0][0]
# __________________________________________________________________________________________________
# weight_output (Dense)           (None, 4)            516         dense_60[0][0]
# __________________________________________________________________________________________________
# bag_output (Dense)              (None, 3)            387         dense_62[0][0]
# __________________________________________________________________________________________________
# footwear_output (Dense)         (None, 3)            387         dense_64[0][0]
# __________________________________________________________________________________________________
# pose_output (Dense)             (None, 3)            387         dense_68[0][0]
# __________________________________________________________________________________________________
# emotion_output (Dense)          (None, 4)            1028        dense_66[0][0]
# ==================================================================================================
# Total params: 28,336,603
# Trainable params: 28,336,603
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import os
import datetime
# Prepare model model saving directory.
# save_dir = os.path.join(os.getcwd(), 'saved_models')
t = datetime.datetime.today()
print(str(datetime.datetime.today()))
save_dir = "/content/gdrive/My Drive/EIP/Assignment5Dataset/saved_models"
model_name = 'A5_'+str(t)+'_model.{epoch:03d}.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)
filepath
# Out:
# 2019-12-27 14:30:02.798792
# '/content/gdrive/My Drive/EIP/Assignment5Dataset/saved_models/A5_2019-12-27 14:30:02.798745_model.{epoch:03d}.h5'

# %%
# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_loss',
                             verbose=1,
                             save_best_only=True)


es = EarlyStopping(monitor='val_loss', verbose=1, patience=5, mode='min')

lr_scheduler = LearningRateScheduler(lr_schedule, verbose=1)

# lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
#                                cooldown=0,
#                                patience=5,
#                                min_lr=0.5e-6)

# callbacks = [checkpoint, lr_reducer, lr_scheduler]
callbacks = [checkpoint,es,lr_scheduler]

# %%
model_output = model.fit_generator(
    generator=train_gen,
    validation_data=valid_gen,
    use_multiprocessing=True,
    workers=6, 
    epochs=50,
    verbose=1,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.001.
# 360/360 [==============================] - 221s 613ms/step - loss: 8.7401 - gender_output_loss: 0.6902 - image_quality_output_loss: 0.9912 - age_output_loss: 1.4467 - weight_output_loss: 1.0095 - bag_output_loss: 0.9429 - footwear_output_loss: 1.0377 - pose_output_loss: 0.9462 - emotion_output_loss: 0.9524 - gender_output_acc: 0.5484 - image_quality_output_acc: 0.5470 - age_output_acc: 0.3929 - weight_output_acc: 0.6352 - bag_output_acc: 0.5556 - footwear_output_acc: 0.4653 - pose_output_acc: 0.6052 - emotion_output_acc: 0.7028 - val_loss: 8.5207 - val_gender_output_loss: 0.6836 - val_image_quality_output_loss: 0.9784 - val_age_output_loss: 1.4344 - val_weight_output_loss: 0.9999 - val_bag_output_loss: 0.9120 - val_footwear_output_loss: 1.0008 - val_pose_output_loss: 0.9000 - val_emotion_output_loss: 0.8944 - val_gender_output_acc: 0.5675 - val_image_quality_output_acc: 0.5546 - val_age_output_acc: 0.3924 - val_weight_output_acc: 0.6215 - val_bag_output_acc: 0.5640 - val_footwear_output_acc: 0.5724 - val_pose_output_acc: 0.6429 - val_emotion_output_acc: 0.7252
#
# Epoch 00001: val_loss improved from inf to 8.52067, saving model to /content/gdrive/My Drive/EIP/Assignment5Dataset/saved_models/A5_2019-12-27 14:30:02.798745_model.001.h5
# Epoch 2/50
# Learning rate:  0.001
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.001.
# 360/360 [==============================] - 215s 598ms/step - loss: 8.5869 - gender_output_loss: 0.6861 - image_quality_output_loss: 0.9837 - age_output_loss: 1.4338 - weight_output_loss: 0.9868 - bag_output_loss: 0.9252 - footwear_output_loss: 0.9939 - pose_output_loss: 0.9353 - emotion_output_loss: 0.9251 - gender_output_acc: 0.5608 - image_quality_output_acc: 0.5534 - age_output_acc: 0.3996 - weight_output_acc: 0.6382 - bag_output_acc: 0.5637 - footwear_output_acc: 0.5307 - pose_output_acc: 0.6135 - emotion_output_acc: 0.7090 - val_loss: 8.4537 - val_gender_output_loss: 0.6830 - val_image_quality_output_loss: 0.9784 - val_age_output_loss: 1.4328 - val_weight_output_loss: 0.9964 - val_bag_output_loss: 0.9107 - val_footwear_output_loss: 0.9434 - val_pose_output_loss: 0.8993 - val_emotion_output_loss: 0.8934 - val_gender_output_acc: 0.5675 - val_image_quality_output_acc: 0.5546 - val_age_output_acc: 0.3924 - val_weight_output_acc: 0.6215 - val_bag_output_acc: 0.5640 - val_footwear_output_acc: 0.5729 - val_pose_output_acc: 0.6429 - val_emotion_output_acc: 0.7252
#
# Epoch 00002: val_loss improved from 8.52067 to 8.45369, saving model to /content/gdrive/My Drive/EIP/Assignment5Dataset/saved_models/A5_2019-12-27 14:30:02.798745_model.002.h5
# Epoch 3/50
# Learning rate:  0.001
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# 359/360 [============================>.] - ETA: 0s - loss: 8.5410 - gender_output_loss: 0.6861 - image_quality_output_loss: 0.9822 - age_output_loss: 1.4301 - weight_output_loss: 0.9843 - bag_output_loss: 0.9213 - footwear_output_loss: 0.9666 - pose_output_loss: 0.9321 - emotion_output_loss: 0.9233 - gender_output_acc: 0.5599 - image_quality_output_acc: 0.5535 - age_output_acc: 0.3995 - weight_output_acc: 0.6381 - bag_output_acc: 0.5636 - footwear_output_acc: 0.5508 - pose_output_acc: 0.6132 - emotion_output_acc: 0.7090
# 360/360 [==============================] - 215s 598ms/step - loss: 8.5409 - gender_output_loss: 0.6862 - image_quality_output_loss: 0.9824 - age_output_loss: 1.4304 - weight_output_loss: 0.9845 - bag_output_loss: 0.9209 - footwear_output_loss: 0.9665 - pose_output_loss: 0.9317 - emotion_output_loss: 0.9232 - gender_output_acc: 0.5597 - image_quality_output_acc: 0.5534 - age_output_acc: 0.3992 - weight_output_acc: 0.6382 - bag_output_acc: 0.5638 - footwear_output_acc: 0.5510 - pose_output_acc: 0.6135 - emotion_output_acc: 0.7090 - val_loss: 8.3800 - val_gender_output_loss: 0.6815 - val_image_quality_output_loss: 0.9757 - val_age_output_loss: 1.4295 - val_weight_output_loss: 0.9893 - val_bag_output_loss: 0.8994 - val_footwear_output_loss: 0.9129 - val_pose_output_loss: 0.8967 - val_emotion_output_loss: 0.8803 - val_gender_output_acc: 0.5675 - val_image_quality_output_acc: 0.5546 - val_age_output_acc: 0.3924 - val_weight_output_acc: 0.6215 - val_bag_output_acc: 0.5640 - val_footwear_output_acc: 0.5799 - val_pose_output_acc: 0.6429 - val_emotion_output_acc: 0.7252
#
# Epoch 00003: val_loss improved from 8.45369 to 8.38003, saving model to /content/gdrive/My Drive/EIP/Assignment5Dataset/saved_models/A5_2019-12-27 14:30:02.798745_model.003.h5
# Epoch 4/50
# Learning rate:  0.001
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# 360/360 [==============================] - 215s 598ms/step - loss: 8.4843 - gender_output_loss: 0.6833 - image_quality_output_loss: 0.9821 - age_output_loss: 1.4221 - weight_output_loss: 0.9806 - bag_output_loss: 0.9177 - footwear_output_loss: 0.9388 - pose_output_loss: 0.9292 - emotion_output_loss: 0.9194 - gender_output_acc: 0.5609 - image_quality_output_acc: 0.5534 - age_output_acc: 0.3997 - weight_output_acc: 0.6382 - bag_output_acc: 0.5635 - footwear_output_acc: 0.5639 - pose_output_acc: 0.6135 - emotion_output_acc: 0.7090 - val_loss: 8.3179 - val_gender_output_loss: 0.6732 - val_image_quality_output_loss: 0.9752 - val_age_output_loss: 1.4234 - val_weight_output_loss: 0.9843 - val_bag_output_loss: 0.8945 - val_footwear_output_loss: 0.8828 - val_pose_output_loss: 0.8939 - val_emotion_output_loss: 0.8789 - val_gender_output_acc: 0.5680 - val_image_quality_output_acc: 0.5546 - val_age_output_acc: 0.3924 - val_weight_output_acc: 0.6215 - val_bag_output_acc: 0.5640 - val_footwear_output_acc: 0.5933 - val_pose_output_acc: 0.6429 - val_emotion_output_acc: 0.7252
#
# Epoch 00004: val_loss improved from 8.38003 to 8.31792, saving model to /content/gdrive/My Drive/EIP/Assignment5Dataset/saved_models/A5_2019-12-27 14:30:02.798745_model.004.h5
# Epoch 5/50
# Learning rate:  0.001
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001.
# 360/360 [==============================] - 215s 598ms/step - loss: 8.3980 - gender_output_loss: 0.6622 - image_quality_output_loss: 0.9800 - age_output_loss: 1.4154 - weight_output_loss: 0.9781 - bag_output_loss: 0.9091 - footwear_output_loss: 0.9050 - pose_output_loss: 0.9190 - emotion_output_loss: 0.9216 - gender_output_acc: 0.5886 - image_quality_output_acc: 0.5533 - age_output_acc: 0.3978 - weight_output_acc: 0.6382 - bag_output_acc: 0.5648 - footwear_output_acc: 0.5883 - pose_output_acc: 0.6135 - emotion_output_acc: 0.7090 - val_loss: 8.1483 - val_gender_output_loss: 0.6215 - val_image_quality_output_loss: 0.9722 - val_age_output_loss: 1.4066 - val_weight_output_loss: 0.9804 - val_bag_output_loss: 0.8829 - val_footwear_output_loss: 0.8306 - val_pose_output_loss: 0.8694 - val_emotion_output_loss: 0.8815 - val_gender_output_acc: 0.6443 - val_image_quality_output_acc: 0.5546 - val_age_output_acc: 0.3859 - val_weight_output_acc: 0.6215 - val_bag_output_acc: 0.5714 - val_footwear_output_acc: 0.6384 - val_pose_output_acc: 0.6429 - val_emotion_output_acc: 0.7252
#
# Epoch 00005: val_loss improved from 8.31792 to 8.14832, saving model to /content/gdrive/My Drive/EIP/Assignment5Dataset/saved_models/A5_2019-12-27 14:30:02.798745_model.005.h5
# Epoch 6/50
# Learning rate:  0.001
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.001.
# 360/360 [==============================] - 215s 598ms/step - loss: 8.2972 - gender_output_loss: 0.6351 - image_quality_output_loss: 0.9774 - age_output_loss: 1.4064 - weight_output_loss: 0.9746 - bag_output_loss: 0.8971 - footwear_output_loss: 0.8816 - pose_output_loss: 0.9023 - emotion_output_loss: 0.9194 - gender_output_acc: 0.6312 - image_quality_output_acc: 0.5532 - age_output_acc: 0.3994 - weight_output_acc: 0.6382 - bag_output_acc: 0.5743 - footwear_output_acc: 0.5968 - pose_output_acc: 0.6135 - emotion_output_acc: 0.7090 - val_loss: 8.0644 - val_gender_output_loss: 0.5966 - val_image_quality_output_loss: 0.9685 - val_age_output_loss: 1.4074 - val_weight_output_loss: 0.9834 - val_bag_output_loss: 0.8771 - val_footwear_output_loss: 0.8214 - val_pose_output_loss: 0.8295 - val_emotion_output_loss: 0.8768 - val_gender_output_acc: 0.6801 - val_image_quality_output_acc: 0.5546 - val_age_output_acc: 0.3894 - val_weight_output_acc: 0.6215 - val_bag_output_acc: 0.5828 - val_footwear_output_acc: 0.6419 - val_pose_output_acc: 0.6429 - val_emotion_output_acc: 0.7252
#
# Epoch 00005: val_loss improved from 8.31792 to 8.14832, saving model to /content/gdrive/My Drive/EIP/Assignment5Dataset/saved_models/A5_2019-12-27 14:30:02.798745_model.005.h5
#
# Epoch 00006: val_loss improved from 8.14832 to 8.06439, saving model to /content/gdrive/My Drive/EIP/Assignment5Dataset/saved_models/A5_2019-12-27 14:30:02.798745_model.006.h5
# Epoch 7/50
# Learning rate:  0.001
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.001.
# 359/360 [============================>.] - ETA: 0s - loss: 8.2126 - gender_output_loss: 0.6171 - image_quality_output_loss: 0.9753 - age_output_loss: 1.4046 - weight_output_loss: 0.9724 - bag_output_loss: 0.8919 - footwear_output_loss: 0.8560 - pose_output_loss: 0.8760 - emotion_output_loss: 0.9169 - gender_output_acc: 0.6563 - image_quality_output_acc: 0.5539 - age_output_acc: 0.4023 - weight_output_acc: 0.6383 - bag_output_acc: 0.5791 - footwear_output_acc: 0.6134 - pose_output_acc: 0.6169 - emotion_output_acc: 0.7092
# Epoch 00006: val_loss improved from 8.14832 to 8.06439, saving model to /content/gdrive/My Drive/EIP/Assignment5Dataset/saved_models/A5_2019-12-27 14:30:02.798745_model.006.h5
# 360/360 [==============================] - 215s 598ms/step - loss: 8.2133 - gender_output_loss: 0.6172 - image_quality_output_loss: 0.9756 - age_output_loss: 1.4048 - weight_output_loss: 0.9726 - bag_output_loss: 0.8916 - footwear_output_loss: 0.8558 - pose_output_loss: 0.8761 - emotion_output_loss: 0.9172 - gender_output_acc: 0.6560 - image_quality_output_acc: 0.5536 - age_output_acc: 0.4019 - weight_output_acc: 0.6382 - bag_output_acc: 0.5793 - footwear_output_acc: 0.6134 - pose_output_acc: 0.6167 - emotion_output_acc: 0.7090 - val_loss: 8.0292 - val_gender_output_loss: 0.5862 - val_image_quality_output_loss: 0.9667 - val_age_output_loss: 1.4063 - val_weight_output_loss: 0.9788 - val_bag_output_loss: 0.8656 - val_footwear_output_loss: 0.8066 - val_pose_output_loss: 0.8388 - val_emotion_output_loss: 0.8770 - val_gender_output_acc: 0.7029 - val_image_quality_output_acc: 0.5546 - val_age_output_acc: 0.3924 - val_weight_output_acc: 0.6215 - val_bag_output_acc: 0.5813 - val_footwear_output_acc: 0.6543 - val_pose_output_acc: 0.6498 - val_emotion_output_acc: 0.7252
#
# Epoch 00007: val_loss improved from 8.06439 to 8.02923, saving model to /content/gdrive/My Drive/EIP/Assignment5Dataset/saved_models/A5_2019-12-27 14:30:02.798745_model.007.h5
# Epoch 8/50
# Learning rate:  0.001
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.001.
# 359/360 [============================>.] - ETA: 0s - loss: 8.1155 - gender_output_loss: 0.5963 - image_quality_output_loss: 0.9733 - age_output_loss: 1.4009 - weight_output_loss: 0.9686 - bag_output_loss: 0.8872 - footwear_output_loss: 0.8409 - pose_output_loss: 0.8342 - emotion_output_loss: 0.9136 - gender_output_acc: 0.6766 - image_quality_output_acc: 0.5540 - age_output_acc: 0.4015 - weight_output_acc: 0.6383 - bag_output_acc: 0.5846 - footwear_output_acc: 0.6212 - pose_output_acc: 0.6300 - emotion_output_acc: 0.7089
# Epoch 00007: val_loss improved from 8.06439 to 8.02923, saving model to /content/gdrive/My Drive/EIP/Assignment5Dataset/saved_models/A5_2019-12-27 14:30:02.798745_model.007.h5
# 360/360 [==============================] - 215s 598ms/step - loss: 8.1148 - gender_output_loss: 0.5961 - image_quality_output_loss: 0.9732 - age_output_loss: 1.4009 - weight_output_loss: 0.9687 - bag_output_loss: 0.8871 - footwear_output_loss: 0.8409 - pose_output_loss: 0.8339 - emotion_output_loss: 0.9136 - gender_output_acc: 0.6766 - image_quality_output_acc: 0.5539 - age_output_acc: 0.4017 - weight_output_acc: 0.6383 - bag_output_acc: 0.5842 - footwear_output_acc: 0.6212 - pose_output_acc: 0.6302 - emotion_output_acc: 0.7090 - val_loss: 7.8548 - val_gender_output_loss: 0.5506 - val_image_quality_output_loss: 0.9620 - val_age_output_loss: 1.4005 - val_weight_output_loss: 0.9724 - val_bag_output_loss: 0.8555 - val_footwear_output_loss: 0.7984 - val_pose_output_loss: 0.7369 - val_emotion_output_loss: 0.8782 - val_gender_output_acc: 0.7073 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3894 - val_weight_output_acc: 0.6215 - val_bag_output_acc: 0.5913 - val_footwear_output_acc: 0.6562 - val_pose_output_acc: 0.6890 - val_emotion_output_acc: 0.7252
#
# Epoch 00008: val_loss improved from 8.02923 to 7.85476, saving model to /content/gdrive/My Drive/EIP/Assignment5Dataset/saved_models/A5_2019-12-27 14:30:02.798745_model.008.h5
# Epoch 9/50
# Learning rate:  0.001
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.001.
# 360/360 [==============================] - 215s 598ms/step - loss: 8.1148 - gender_output_loss: 0.5961 - image_quality_output_loss: 0.9732 - age_output_loss: 1.4009 - weight_output_loss: 0.9687 - bag_output_loss: 0.8871 - footwear_output_loss: 0.8409 - pose_output_loss: 0.8339 - emotion_output_loss: 0.9136 - gender_output_acc: 0.6766 - image_quality_output_acc: 0.5539 - age_output_acc: 0.4017 - weight_output_acc: 0.6383 - bag_output_acc: 0.5842 - footwear_output_acc: 0.6212 - pose_output_acc: 0.6302 - emotion_output_acc: 0.7090 - val_loss: 7.8548 - val_gender_output_loss: 0.5506 - val_image_quality_output_loss: 0.9620 - val_age_output_loss: 1.4005 - val_weight_output_loss: 0.9724 - val_bag_output_loss: 0.8555 - val_footwear_output_loss: 0.7984 - val_pose_output_loss: 0.7369 - val_emotion_output_loss: 0.8782 - val_gender_output_acc: 0.7073 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3894 - val_weight_output_acc: 0.6215 - val_bag_output_acc: 0.5913 - val_footwear_output_acc: 0.6562 - val_pose_output_acc: 0.6890 - val_emotion_output_acc: 0.7252
# 360/360 [==============================] - 216s 599ms/step - loss: 8.0168 - gender_output_loss: 0.5735 - image_quality_output_loss: 0.9706 - age_output_loss: 1.3966 - weight_output_loss: 0.9678 - bag_output_loss: 0.8813 - footwear_output_loss: 0.8305 - pose_output_loss: 0.7915 - emotion_output_loss: 0.9068 - gender_output_acc: 0.6992 - image_quality_output_acc: 0.5533 - age_output_acc: 0.3991 - weight_output_acc: 0.6382 - bag_output_acc: 0.5856 - footwear_output_acc: 0.6288 - pose_output_acc: 0.6501 - emotion_output_acc: 0.7090 - val_loss: 7.8090 - val_gender_output_loss: 0.5376 - val_image_quality_output_loss: 0.9582 - val_age_output_loss: 1.4061 - val_weight_output_loss: 0.9740 - val_bag_output_loss: 0.8546 - val_footwear_output_loss: 0.7981 - val_pose_output_loss: 0.7061 - val_emotion_output_loss: 0.8713 - val_gender_output_acc: 0.7381 - val_image_quality_output_acc: 0.5546 - val_age_output_acc: 0.3938 - val_weight_output_acc: 0.6215 - val_bag_output_acc: 0.5828 - val_footwear_output_acc: 0.6592 - val_pose_output_acc: 0.7014 - val_emotion_output_acc: 0.7252
#
# Epoch 00009: val_loss improved from 7.85476 to 7.80898, saving model to /content/gdrive/My Drive/EIP/Assignment5Dataset/saved_models/A5_2019-12-27 14:30:02.798745_model.009.h5
# Epoch 10/50
# Learning rate:  0.001
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.001.
# 360/360 [==============================] - 216s 599ms/step - loss: 7.8966 - gender_output_loss: 0.5502 - image_quality_output_loss: 0.9653 - age_output_loss: 1.3895 - weight_output_loss: 0.9662 - bag_output_loss: 0.8760 - footwear_output_loss: 0.8180 - pose_output_loss: 0.7387 - emotion_output_loss: 0.8980 - gender_output_acc: 0.7151 - image_quality_output_acc: 0.5541 - age_output_acc: 0.4017 - weight_output_acc: 0.6381 - bag_output_acc: 0.5928 - footwear_output_acc: 0.6329 - pose_output_acc: 0.6865 - emotion_output_acc: 0.7090 - val_loss: 7.6935 - val_gender_output_loss: 0.5149 - val_image_quality_output_loss: 0.9570 - val_age_output_loss: 1.3953 - val_weight_output_loss: 0.9768 - val_bag_output_loss: 0.8563 - val_footwear_output_loss: 0.7785 - val_pose_output_loss: 0.6473 - val_emotion_output_loss: 0.8697 - val_gender_output_acc: 0.7450 - val_image_quality_output_acc: 0.5551 - val_age_output_acc: 0.3859 - val_weight_output_acc: 0.6215 - val_bag_output_acc: 0.5823 - val_footwear_output_acc: 0.6706 - val_pose_output_acc: 0.7411 - val_emotion_output_acc: 0.7252
#
# Epoch 00010: val_loss improved from 7.80898 to 7.69351, saving model to /content/gdrive/My Drive/EIP/Assignment5Dataset/saved_models/A5_2019-12-27 14:30:02.798745_model.010.h5
# Epoch 11/50
# Learning rate:  0.001
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.001.
# 359/360 [============================>.] - ETA: 0s - loss: 7.8063 - gender_output_loss: 0.5182 - image_quality_output_loss: 0.9628 - age_output_loss: 1.3879 - weight_output_loss: 0.9627 - bag_output_loss: 0.8683 - footwear_output_loss: 0.8080 - pose_output_loss: 0.7081 - emotion_output_loss: 0.8963 - gender_output_acc: 0.7437 - image_quality_output_acc: 0.5551 - age_output_acc: 0.3992 - weight_output_acc: 0.6382 - bag_output_acc: 0.6016 - footwear_output_acc: 0.6416 - pose_output_acc: 0.6999 - emotion_output_acc: 0.7087
# Epoch 00010: val_loss improved from 7.80898 to 7.69351, saving model to /content/gdrive/My Drive/EIP/Assignment5Dataset/saved_models/A5_2019-12-27 14:30:02.798745_model.010.h5
# 360/360 [==============================] - 216s 599ms/step - loss: 7.8064 - gender_output_loss: 0.5183 - image_quality_output_loss: 0.9632 - age_output_loss: 1.3877 - weight_output_loss: 0.9629 - bag_output_loss: 0.8683 - footwear_output_loss: 0.8085 - pose_output_loss: 0.7077 - emotion_output_loss: 0.8959 - gender_output_acc: 0.7438 - image_quality_output_acc: 0.5547 - age_output_acc: 0.3991 - weight_output_acc: 0.6382 - bag_output_acc: 0.6016 - footwear_output_acc: 0.6412 - pose_output_acc: 0.7001 - emotion_output_acc: 0.7090 - val_loss: 7.6081 - val_gender_output_loss: 0.4907 - val_image_quality_output_loss: 0.9506 - val_age_output_loss: 1.3954 - val_weight_output_loss: 0.9749 - val_bag_output_loss: 0.8421 - val_footwear_output_loss: 0.7744 - val_pose_output_loss: 0.6054 - val_emotion_output_loss: 0.8771 - val_gender_output_acc: 0.7574 - val_image_quality_output_acc: 0.5575 - val_age_output_acc: 0.3790 - val_weight_output_acc: 0.6210 - val_bag_output_acc: 0.6017 - val_footwear_output_acc: 0.6746 - val_pose_output_acc: 0.7520 - val_emotion_output_acc: 0.7252
#
# Epoch 00011: val_loss improved from 7.69351 to 7.60812, saving model to /content/gdrive/My Drive/EIP/Assignment5Dataset/saved_models/A5_2019-12-27 14:30:02.798745_model.011.h5
# Epoch 12/50
# Learning rate:  0.001
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.001.
# 360/360 [==============================] - 216s 599ms/step - loss: 7.7047 - gender_output_loss: 0.4927 - image_quality_output_loss: 0.9618 - age_output_loss: 1.3766 - weight_output_loss: 0.9574 - bag_output_loss: 0.8610 - footwear_output_loss: 0.8028 - pose_output_loss: 0.6725 - emotion_output_loss: 0.8915 - gender_output_acc: 0.7569 - image_quality_output_acc: 0.5529 - age_output_acc: 0.4036 - weight_output_acc: 0.6385 - bag_output_acc: 0.6050 - footwear_output_acc: 0.6417 - pose_output_acc: 0.7158 - emotion_output_acc: 0.7090 - val_loss: 7.4675 - val_gender_output_loss: 0.4514 - val_image_quality_output_loss: 0.9464 - val_age_output_loss: 1.3847 - val_weight_output_loss: 0.9663 - val_bag_output_loss: 0.8363 - val_footwear_output_loss: 0.7641 - val_pose_output_loss: 0.5726 - val_emotion_output_loss: 0.8533 - val_gender_output_acc: 0.7882 - val_image_quality_output_acc: 0.5570 - val_age_output_acc: 0.3909 - val_weight_output_acc: 0.6215 - val_bag_output_acc: 0.6057 - val_footwear_output_acc: 0.6751 - val_pose_output_acc: 0.7693 - val_emotion_output_acc: 0.7252
#
# Epoch 00012: val_loss improved from 7.60812 to 7.46746, saving model to /content/gdrive/My Drive/EIP/Assignment5Dataset/saved_models/A5_2019-12-27 14:30:02.798745_model.012.h5
# Epoch 13/50
# Learning rate:  0.001
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.001.
# 359/360 [============================>.] - ETA: 0s - loss: 7.6103 - gender_output_loss: 0.4687 - image_quality_output_loss: 0.9576 - age_output_loss: 1.3707 - weight_output_loss: 0.9569 - bag_output_loss: 0.8526 - footwear_output_loss: 0.7884 - pose_output_loss: 0.6421 - emotion_output_loss: 0.8880 - gender_output_acc: 0.7742 - image_quality_output_acc: 0.5569 - age_output_acc: 0.4034 - weight_output_acc: 0.6392 - bag_output_acc: 0.6124 - footwear_output_acc: 0.6482 - pose_output_acc: 0.7325 - emotion_output_acc: 0.7091
# Epoch 00012: val_loss improved from 7.60812 to 7.46746, saving model to /content/gdrive/My Drive/EIP/Assignment5Dataset/saved_models/A5_2019-12-27 14:30:02.798745_model.012.h5
# 360/360 [==============================] - 216s 599ms/step - loss: 7.6103 - gender_output_loss: 0.4689 - image_quality_output_loss: 0.9579 - age_output_loss: 1.3707 - weight_output_loss: 0.9566 - bag_output_loss: 0.8529 - footwear_output_loss: 0.7885 - pose_output_loss: 0.6415 - emotion_output_loss: 0.8878 - gender_output_acc: 0.7741 - image_quality_output_acc: 0.5568 - age_output_acc: 0.4031 - weight_output_acc: 0.6394 - bag_output_acc: 0.6122 - footwear_output_acc: 0.6483 - pose_output_acc: 0.7327 - emotion_output_acc: 0.7091 - val_loss: 7.4060 - val_gender_output_loss: 0.4427 - val_image_quality_output_loss: 0.9380 - val_age_output_loss: 1.3829 - val_weight_output_loss: 0.9676 - val_bag_output_loss: 0.8274 - val_footwear_output_loss: 0.7528 - val_pose_output_loss: 0.5483 - val_emotion_output_loss: 0.8546 - val_gender_output_acc: 0.7882 - val_image_quality_output_acc: 0.5590 - val_age_output_acc: 0.3854 - val_weight_output_acc: 0.6245 - val_bag_output_acc: 0.6181 - val_footwear_output_acc: 0.6801 - val_pose_output_acc: 0.7808 - val_emotion_output_acc: 0.7252
#
# Epoch 00013: val_loss improved from 7.46746 to 7.40597, saving model to /content/gdrive/My Drive/EIP/Assignment5Dataset/saved_models/A5_2019-12-27 14:30:02.798745_model.013.h5
# Epoch 14/50
# Learning rate:  0.001
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.001.
# 359/360 [============================>.] - ETA: 0s - loss: 7.4966 - gender_output_loss: 0.4345 - image_quality_output_loss: 0.9510 - age_output_loss: 1.3642 - weight_output_loss: 0.9494 - bag_output_loss: 0.8448 - footwear_output_loss: 0.7784 - pose_output_loss: 0.6095 - emotion_output_loss: 0.8829 - gender_output_acc: 0.7997 - image_quality_output_acc: 0.5570 - age_output_acc: 0.4029 - weight_output_acc: 0.6391 - bag_output_acc: 0.6206 - footwear_output_acc: 0.6547 - pose_output_acc: 0.7525 - emotion_output_acc: 0.7093
#
# 360/360 [==============================] - 216s 599ms/step - loss: 7.5001 - gender_output_loss: 0.4347 - image_quality_output_loss: 0.9513 - age_output_loss: 1.3643 - weight_output_loss: 0.9498 - bag_output_loss: 0.8449 - footwear_output_loss: 0.7788 - pose_output_loss: 0.6105 - emotion_output_loss: 0.8837 - gender_output_acc: 0.7994 - image_quality_output_acc: 0.5568 - age_output_acc: 0.4027 - weight_output_acc: 0.6390 - bag_output_acc: 0.6206 - footwear_output_acc: 0.6546 - pose_output_acc: 0.7523 - emotion_output_acc: 0.7089 - val_loss: 7.3878 - val_gender_output_loss: 0.4380 - val_image_quality_output_loss: 0.9325 - val_age_output_loss: 1.3830 - val_weight_output_loss: 0.9617 - val_bag_output_loss: 0.8202 - val_footwear_output_loss: 0.7675 - val_pose_output_loss: 0.5354 - val_emotion_output_loss: 0.8580 - val_gender_output_acc: 0.7991 - val_image_quality_output_acc: 0.5620 - val_age_output_acc: 0.3854 - val_weight_output_acc: 0.6275 - val_bag_output_acc: 0.6329 - val_footwear_output_acc: 0.6766 - val_pose_output_acc: 0.7907 - val_emotion_output_acc: 0.7237
#
# Epoch 00014: val_loss improved from 7.40597 to 7.38784, saving model to /content/gdrive/My Drive/EIP/Assignment5Dataset/saved_models/A5_2019-12-27 14:30:02.798745_model.014.h5
# Epoch 15/50
# Learning rate:  0.001
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.001.
# 359/360 [============================>.] - ETA: 0s - loss: 7.4102 - gender_output_loss: 0.4149 - image_quality_output_loss: 0.9502 - age_output_loss: 1.3566 - weight_output_loss: 0.9472 - bag_output_loss: 0.8348 - footwear_output_loss: 0.7652 - pose_output_loss: 0.5830 - emotion_output_loss: 0.8802 - gender_output_acc: 0.8094 - image_quality_output_acc: 0.5580 - age_output_acc: 0.4066 - weight_output_acc: 0.6385 - bag_output_acc: 0.6317 - footwear_output_acc: 0.6601 - pose_output_acc: 0.7617 - emotion_output_acc: 0.7086
# 360/360 [==============================] - 216s 599ms/step - loss: 7.4107 - gender_output_loss: 0.4151 - image_quality_output_loss: 0.9503 - age_output_loss: 1.3566 - weight_output_loss: 0.9468 - bag_output_loss: 0.8351 - footwear_output_loss: 0.7654 - pose_output_loss: 0.5831 - emotion_output_loss: 0.8801 - gender_output_acc: 0.8090 - image_quality_output_acc: 0.5577 - age_output_acc: 0.4065 - weight_output_acc: 0.6389 - bag_output_acc: 0.6313 - footwear_output_acc: 0.6597 - pose_output_acc: 0.7615 - emotion_output_acc: 0.7086 - val_loss: 7.3390 - val_gender_output_loss: 0.4137 - val_image_quality_output_loss: 0.9344 - val_age_output_loss: 1.3752 - val_weight_output_loss: 0.9609 - val_bag_output_loss: 0.8114 - val_footwear_output_loss: 0.7669 - val_pose_output_loss: 0.5195 - val_emotion_output_loss: 0.8694 - val_gender_output_acc: 0.8046 - val_image_quality_output_acc: 0.5605 - val_age_output_acc: 0.3924 - val_weight_output_acc: 0.6235 - val_bag_output_acc: 0.6344 - val_footwear_output_acc: 0.6701 - val_pose_output_acc: 0.7887 - val_emotion_output_acc: 0.7242
#
# Epoch 00015: val_loss improved from 7.38784 to 7.33895, saving model to /content/gdrive/My Drive/EIP/Assignment5Dataset/saved_models/A5_2019-12-27 14:30:02.798745_model.015.h5
# Epoch 16/50
# Learning rate:  0.001
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.001.
# 360/360 [==============================] - 216s 599ms/step - loss: 7.3301 - gender_output_loss: 0.4005 - image_quality_output_loss: 0.9488 - age_output_loss: 1.3484 - weight_output_loss: 0.9388 - bag_output_loss: 0.8320 - footwear_output_loss: 0.7522 - pose_output_loss: 0.5584 - emotion_output_loss: 0.8768 - gender_output_acc: 0.8187 - image_quality_output_acc: 0.5588 - age_output_acc: 0.4073 - weight_output_acc: 0.6391 - bag_output_acc: 0.6285 - footwear_output_acc: 0.6697 - pose_output_acc: 0.7719 - emotion_output_acc: 0.7089 - val_loss: 7.3217 - val_gender_output_loss: 0.4133 - val_image_quality_output_loss: 0.9323 - val_age_output_loss: 1.3824 - val_weight_output_loss: 0.9655 - val_bag_output_loss: 0.8072 - val_footwear_output_loss: 0.7655 - val_pose_output_loss: 0.5086 - val_emotion_output_loss: 0.8558 - val_gender_output_acc: 0.8036 - val_image_quality_output_acc: 0.5595 - val_age_output_acc: 0.3919 - val_weight_output_acc: 0.6235 - val_bag_output_acc: 0.6419 - val_footwear_output_acc: 0.6756 - val_pose_output_acc: 0.7937 - val_emotion_output_acc: 0.7247
#
# Epoch 00016: val_loss improved from 7.33895 to 7.32170, saving model to /content/gdrive/My Drive/EIP/Assignment5Dataset/saved_models/A5_2019-12-27 14:30:02.798745_model.016.h5
# Epoch 17/50
# Learning rate:  0.0001
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.0001.
# 360/360 [==============================] - 216s 599ms/step - loss: 7.0462 - gender_output_loss: 0.3422 - image_quality_output_loss: 0.9316 - age_output_loss: 1.3202 - weight_output_loss: 0.9204 - bag_output_loss: 0.8007 - footwear_output_loss: 0.7160 - pose_output_loss: 0.4900 - emotion_output_loss: 0.8652 - gender_output_acc: 0.8480 - image_quality_output_acc: 0.5616 - age_output_acc: 0.4181 - weight_output_acc: 0.6407 - bag_output_acc: 0.6508 - footwear_output_acc: 0.6850 - pose_output_acc: 0.8037 - emotion_output_acc: 0.7086 - val_loss: 7.2436 - val_gender_output_loss: 0.3918 - val_image_quality_output_loss: 0.9202 - val_age_output_loss: 1.3694 - val_weight_output_loss: 0.9567 - val_bag_output_loss: 0.8048 - val_footwear_output_loss: 0.7543 - val_pose_output_loss: 0.5023 - val_emotion_output_loss: 0.8594 - val_gender_output_acc: 0.8234 - val_image_quality_output_acc: 0.5685 - val_age_output_acc: 0.3943 - val_weight_output_acc: 0.6255 - val_bag_output_acc: 0.6379 - val_footwear_output_acc: 0.6855 - val_pose_output_acc: 0.7971 - val_emotion_output_acc: 0.7222
#
# Epoch 00017: val_loss improved from 7.32170 to 7.24364, saving model to /content/gdrive/My Drive/EIP/Assignment5Dataset/saved_models/A5_2019-12-27 14:30:02.798745_model.017.h5
# Epoch 18/50
# Learning rate:  0.0001
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.0001.
# 360/360 [==============================] - 216s 600ms/step - loss: 6.9270 - gender_output_loss: 0.3125 - image_quality_output_loss: 0.9247 - age_output_loss: 1.3036 - weight_output_loss: 0.9149 - bag_output_loss: 0.7901 - footwear_output_loss: 0.7051 - pose_output_loss: 0.4610 - emotion_output_loss: 0.8632 - gender_output_acc: 0.8656 - image_quality_output_acc: 0.5641 - age_output_acc: 0.4270 - weight_output_acc: 0.6432 - bag_output_acc: 0.6593 - footwear_output_acc: 0.6868 - pose_output_acc: 0.8202 - emotion_output_acc: 0.7085 - val_loss: 7.2448 - val_gender_output_loss: 0.3973 - val_image_quality_output_loss: 0.9202 - val_age_output_loss: 1.3677 - val_weight_output_loss: 0.9572 - val_bag_output_loss: 0.8075 - val_footwear_output_loss: 0.7509 - val_pose_output_loss: 0.5012 - val_emotion_output_loss: 0.8588 - val_gender_output_acc: 0.8219 - val_image_quality_output_acc: 0.5694 - val_age_output_acc: 0.3958 - val_weight_output_acc: 0.6235 - val_bag_output_acc: 0.6379 - val_footwear_output_acc: 0.6900 - val_pose_output_acc: 0.8011 - val_emotion_output_acc: 0.7212
#
# Epoch 00018: val_loss did not improve from 7.24364
# Epoch 19/50
# Learning rate:  0.0001
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.0001.
# 359/360 [============================>.] - ETA: 0s - loss: 6.8308 - gender_output_loss: 0.3013 - image_quality_output_loss: 0.9192 - age_output_loss: 1.2905 - weight_output_loss: 0.9084 - bag_output_loss: 0.7784 - footwear_output_loss: 0.6876 - pose_output_loss: 0.4387 - emotion_output_loss: 0.8615 - gender_output_acc: 0.8729 - image_quality_output_acc: 0.5643 - age_output_acc: 0.4264 - weight_output_acc: 0.6427 - bag_output_acc: 0.6677 - footwear_output_acc: 0.6985 - pose_output_acc: 0.8283 - emotion_output_acc: 0.7090Learning rate:  0.0001
#
# Epoch 00018: val_loss did not improve from 7.24364
# 360/360 [==============================] - 216s 601ms/step - loss: 6.8328 - gender_output_loss: 0.3012 - image_quality_output_loss: 0.9190 - age_output_loss: 1.2912 - weight_output_loss: 0.9089 - bag_output_loss: 0.7779 - footwear_output_loss: 0.6878 - pose_output_loss: 0.4390 - emotion_output_loss: 0.8623 - gender_output_acc: 0.8730 - image_quality_output_acc: 0.5645 - age_output_acc: 0.4260 - weight_output_acc: 0.6424 - bag_output_acc: 0.6680 - footwear_output_acc: 0.6985 - pose_output_acc: 0.8282 - emotion_output_acc: 0.7086 - val_loss: 7.2820 - val_gender_output_loss: 0.4055 - val_image_quality_output_loss: 0.9142 - val_age_output_loss: 1.3725 - val_weight_output_loss: 0.9603 - val_bag_output_loss: 0.8052 - val_footwear_output_loss: 0.7598 - val_pose_output_loss: 0.5165 - val_emotion_output_loss: 0.8618 - val_gender_output_acc: 0.8175 - val_image_quality_output_acc: 0.5719 - val_age_output_acc: 0.3983 - val_weight_output_acc: 0.6200 - val_bag_output_acc: 0.6463 - val_footwear_output_acc: 0.6806 - val_pose_output_acc: 0.7946 - val_emotion_output_acc: 0.7222
#
# Epoch 00019: val_loss did not improve from 7.24364
# Epoch 20/50
# Learning rate:  0.0001
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.0001.
# 360/360 [==============================] - 216s 600ms/step - loss: 6.7649 - gender_output_loss: 0.2858 - image_quality_output_loss: 0.9159 - age_output_loss: 1.2764 - weight_output_loss: 0.9004 - bag_output_loss: 0.7778 - footwear_output_loss: 0.6850 - pose_output_loss: 0.4259 - emotion_output_loss: 0.8594 - gender_output_acc: 0.8786 - image_quality_output_acc: 0.5656 - age_output_acc: 0.4321 - weight_output_acc: 0.6426 - bag_output_acc: 0.6666 - footwear_output_acc: 0.6987 - pose_output_acc: 0.8360 - emotion_output_acc: 0.7082 - val_loss: 7.3447 - val_gender_output_loss: 0.4213 - val_image_quality_output_loss: 0.9113 - val_age_output_loss: 1.3777 - val_weight_output_loss: 0.9625 - val_bag_output_loss: 0.8111 - val_footwear_output_loss: 0.7728 - val_pose_output_loss: 0.5356 - val_emotion_output_loss: 0.8637 - val_gender_output_acc: 0.8199 - val_image_quality_output_acc: 0.5694 - val_age_output_acc: 0.4023 - val_weight_output_acc: 0.6186 - val_bag_output_acc: 0.6429 - val_footwear_output_acc: 0.6820 - val_pose_output_acc: 0.8036 - val_emotion_output_acc: 0.7183
#
# Epoch 00020: val_loss did not improve from 7.24364
# Epoch 21/50
# Learning rate:  0.0001
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.0001.
# 359/360 [============================>.] - ETA: 0s - loss: 6.6797 - gender_output_loss: 0.2714 - image_quality_output_loss: 0.9108 - age_output_loss: 1.2672 - weight_output_loss: 0.8945 - bag_output_loss: 0.7636 - footwear_output_loss: 0.6683 - pose_output_loss: 0.4119 - emotion_output_loss: 0.8584 - gender_output_acc: 0.8904 - image_quality_output_acc: 0.5675 - age_output_acc: 0.4341 - weight_output_acc: 0.6433 - bag_output_acc: 0.6742 - footwear_output_acc: 0.7062 - pose_output_acc: 0.8379 - emotion_output_acc: 0.7086
# Epoch 00020: val_loss did not improve from 7.24364
# 360/360 [==============================] - 216s 600ms/step - loss: 6.6787 - gender_output_loss: 0.2715 - image_quality_output_loss: 0.9111 - age_output_loss: 1.2672 - weight_output_loss: 0.8945 - bag_output_loss: 0.7633 - footwear_output_loss: 0.6678 - pose_output_loss: 0.4117 - emotion_output_loss: 0.8580 - gender_output_acc: 0.8905 - image_quality_output_acc: 0.5671 - age_output_acc: 0.4342 - weight_output_acc: 0.6433 - bag_output_acc: 0.6744 - footwear_output_acc: 0.7063 - pose_output_acc: 0.8380 - emotion_output_acc: 0.7087 - val_loss: 7.3015 - val_gender_output_loss: 0.4064 - val_image_quality_output_loss: 0.9121 - val_age_output_loss: 1.3736 - val_weight_output_loss: 0.9635 - val_bag_output_loss: 0.8078 - val_footwear_output_loss: 0.7629 - val_pose_output_loss: 0.5257 - val_emotion_output_loss: 0.8628 - val_gender_output_acc: 0.8120 - val_image_quality_output_acc: 0.5640 - val_age_output_acc: 0.4038 - val_weight_output_acc: 0.6240 - val_bag_output_acc: 0.6453 - val_footwear_output_acc: 0.6875 - val_pose_output_acc: 0.7981 - val_emotion_output_acc: 0.7222
#
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.0001.
#
# Epoch 00021: val_loss did not improve from 7.24364
# Epoch 22/50
# Learning rate:  0.0001
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.0001.
# 360/360 [==============================] - 216s 601ms/step - loss: 6.6060 - gender_output_loss: 0.2610 - image_quality_output_loss: 0.9051 - age_output_loss: 1.2549 - weight_output_loss: 0.8874 - bag_output_loss: 0.7548 - footwear_output_loss: 0.6626 - pose_output_loss: 0.3940 - emotion_output_loss: 0.8587 - gender_output_acc: 0.8952 - image_quality_output_acc: 0.5672 - age_output_acc: 0.4427 - weight_output_acc: 0.6490 - bag_output_acc: 0.6836 - footwear_output_acc: 0.7054 - pose_output_acc: 0.8495 - emotion_output_acc: 0.7086 - val_loss: 7.3514 - val_gender_output_loss: 0.4339 - val_image_quality_output_loss: 0.9124 - val_age_output_loss: 1.3757 - val_weight_output_loss: 0.9615 - val_bag_output_loss: 0.8126 - val_footwear_output_loss: 0.7670 - val_pose_output_loss: 0.5344 - val_emotion_output_loss: 0.8660 - val_gender_output_acc: 0.8170 - val_image_quality_output_acc: 0.5595 - val_age_output_acc: 0.3998 - val_weight_output_acc: 0.6250 - val_bag_output_acc: 0.6429 - val_footwear_output_acc: 0.6900 - val_pose_output_acc: 0.8021 - val_emotion_output_acc: 0.7207
#
# Epoch 00022: val_loss did not improve from 7.24364
# Epoch 00022: early stopping

# %%
from keras.utils import plot_model
plot_model(model, to_file='/content/gdrive/My Drive/EIP/Assignment5Dataset/model.png')
