# %% [markdown]
# <a href="https://colab.research.google.com/github/csharpshooter/EIP/blob/master/A5/Assignment5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# mount gdrive and unzip data
from google.colab import drive
drive.mount('/content/gdrive')
# !unzip -q "/content/gdrive/My Drive/EIP/Assignment5Dataset/hvc_data.zip"
# look for `hvc_annotations.csv` file and `resized` dir
# %ls
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# gdrive/  hvc_annotations.csv  resized/  sample_data/

# %%
# %tensorflow_version 1.x

import cv2
import json

import numpy as np
import pandas as pd

from functools import partial
from pathlib import Path 
from tqdm import tqdm

from google.colab.patches import cv2_imshow

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, OneHotEncoder


from keras.applications import VGG16
from keras.layers.core import Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.layers import Input
from keras.models import Model
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping
from keras.callbacks import ReduceLROnPlateau
# Out:
# Using TensorFlow backend.

# %%
# load annotations
df = pd.read_csv("hvc_annotations.csv")
del df["filename"] # remove unwanted column
df.head()
# Out:
#    gender imagequality    age  ...        emotion        bodypose     image_path
# 0    male      Average  35-45  ...        Neutral  Front-Frontish  resized/1.jpg
# 1  female      Average  35-45  ...  Angry/Serious  Front-Frontish  resized/2.jpg
# 2    male         Good  45-55  ...        Neutral  Front-Frontish  resized/3.jpg
# 3    male         Good  45-55  ...        Neutral  Front-Frontish  resized/4.jpg
# 4  female         Good  35-45  ...        Neutral  Front-Frontish  resized/5.jpg
#
# [5 rows x 9 columns]

# %%
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
# print('Using real-time data augmentation.')  
# This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=90,
        # randomly shift images horizontally
        #width_shift_range=0.1,
        # randomly shift images vertically
        #height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=True,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        #preprocessing_function=get_random_eraser(v_l=0, v_h=1, pixel_level=pixel_level),
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        #validation_split=0.15
        )

# %%
# one hot encoding of labels

one_hot_df = pd.concat([
    df[["image_path"]],
    pd.get_dummies(df.gender, prefix="gender"),
    pd.get_dummies(df.imagequality, prefix="imagequality"),
    pd.get_dummies(df.age, prefix="age"),
    pd.get_dummies(df.weight, prefix="weight"),
    pd.get_dummies(df.carryingbag, prefix="carryingbag"),  
    pd.get_dummies(df.footwear, prefix="footwear"),
    pd.get_dummies(df.emotion, prefix="emotion"),
    pd.get_dummies(df.bodypose, prefix="bodypose"),
], axis = 1)

one_hot_df.head().T
# Out:
#                                                   0  ...              4
# image_path                            resized/1.jpg  ...  resized/5.jpg
# gender_female                                     0  ...              1
# gender_male                                       1  ...              0
# imagequality_Average                              1  ...              0
# imagequality_Bad                                  0  ...              0
# imagequality_Good                                 0  ...              1
# age_15-25                                         0  ...              0
# age_25-35                                         0  ...              0
# age_35-45                                         1  ...              1
# age_45-55                                         0  ...              0
# age_55+                                           0  ...              0
# weight_normal-healthy                             1  ...              0
# weight_over-weight                                0  ...              0
# weight_slightly-overweight                        0  ...              1
# weight_underweight                                0  ...              0
# carryingbag_Daily/Office/Work Bag                 0  ...              0
# carryingbag_Grocery/Home/Plastic Bag              1  ...              0
# carryingbag_None                                  0  ...              1
# footwear_CantSee                                  0  ...              1
# footwear_Fancy                                    0  ...              0
# footwear_Normal                                   1  ...              0
# emotion_Angry/Serious                             0  ...              0
# emotion_Happy                                     0  ...              0
# emotion_Neutral                                   1  ...              1
# emotion_Sad                                       0  ...              0
# bodypose_Back                                     0  ...              0
# bodypose_Front-Frontish                           1  ...              1
# bodypose_Side                                     0  ...              0
#
# [28 rows x 5 columns]

# %%
import keras
import numpy as np

# Label columns per attribute
_gender_cols_ = [col for col in one_hot_df.columns if col.startswith("gender")]
_imagequality_cols_ = [col for col in one_hot_df.columns if col.startswith("imagequality")]
_age_cols_ = [col for col in one_hot_df.columns if col.startswith("age")]
_weight_cols_ = [col for col in one_hot_df.columns if col.startswith("weight")]
_carryingbag_cols_ = [col for col in one_hot_df.columns if col.startswith("carryingbag")]
_footwear_cols_ = [col for col in one_hot_df.columns if col.startswith("footwear")]
_emotion_cols_ = [col for col in one_hot_df.columns if col.startswith("emotion")]
_bodypose_cols_ = [col for col in one_hot_df.columns if col.startswith("bodypose")]

class PersonDataGenerator(keras.utils.Sequence):
    """Ground truth data generator"""

    
    def __init__(self, df, batch_size=32, shuffle=True, augmentation=None):
        self.df = df
        self.batch_size=batch_size
        self.shuffle = shuffle
        self.on_epoch_end()
        self.augmentation = augmentation

    def __len__(self):
        return int(np.floor(self.df.shape[0] / self.batch_size))

    def __getitem__(self, index):
        """fetch batched images and targets"""
        batch_slice = slice(index * self.batch_size, (index + 1) * self.batch_size)
        items = self.df.iloc[batch_slice]
        image = np.stack([cv2.imread(item["image_path"]) for _, item in items.iterrows()])

        # if self.augmentation is not None:
        #     image = self.augmentation.flow(image,batch_size=self.batch_size,shuffle=False).next()

        target = {
            "gender_output": items[_gender_cols_].values,
            "image_quality_output": items[_imagequality_cols_].values,
            "age_output": items[_age_cols_].values,
            "weight_output": items[_weight_cols_].values,
            "bag_output": items[_carryingbag_cols_].values,
            "pose_output": items[_bodypose_cols_].values,
            "footwear_output": items[_footwear_cols_].values,
            "emotion_output": items[_emotion_cols_].values,
        }

        return image, target

    def on_epoch_end(self):
        """Updates indexes after each epoch"""
        if self.shuffle == True:
            self.df = self.df.sample(frac=1).reset_index(drop=True)

# %%
from sklearn.model_selection import train_test_split
train_df, val_df = train_test_split(one_hot_df, test_size=0.15)
train_df.shape, val_df.shape
# Out:
# ((11537, 28), (2036, 28))

# %%
train_df.head()
# Out:
#               image_path  gender_female  ...  bodypose_Front-Frontish  bodypose_Side
# 12310  resized/12312.jpg              0  ...                        1              0
# 11601  resized/11603.jpg              0  ...                        1              0
# 5179    resized/5180.jpg              1  ...                        0              0
# 4936    resized/4937.jpg              0  ...                        1              0
# 1834    resized/1835.jpg              1  ...                        1              0
#
# [5 rows x 28 columns]

# %%
# create train and validation data generators
train_gen = PersonDataGenerator(train_df, batch_size=32, shuffle=False, augmentation=datagen)
valid_gen = PersonDataGenerator(val_df, batch_size=64, shuffle=False)

# %%
# get number of output units from data
images, targets = next(iter(train_gen))
num_units = { k.split("_output")[0]:v.shape[1] for k, v in targets.items()}
num_units
# Out:
# {'age': 5,
#  'bag': 3,
#  'emotion': 4,
#  'footwear': 3,
#  'gender': 2,
#  'image_quality': 3,
#  'pose': 3,
#  'weight': 4}

# %%
backbone = VGG16(
    weights=None, 
    include_top=False, 
    input_tensor=Input(shape=(224, 224, 3))
)

neck = backbone.output
neck = Flatten(name="flatten")(neck)
neck = Dense(512, activation="relu")(neck)


def build_tower(in_layer):
    neck = Dropout(0.2)(in_layer)
    neck = Dense(128, activation="relu")(neck)
    neck = Dropout(0.3)(neck)
    neck = Dense(128, activation="relu")(neck)
    return neck


def build_tower_emotion(in_layer):
    neck = Dropout(0.4)(in_layer)
    neck = Dense(256, activation="relu")(neck)
    neck = Dropout(0.4)(neck)
    neck = Dense(256, activation="relu")(neck)
    return neck

def build_head(name, in_layer):
    return Dense(
        num_units[name], activation="softmax", name=f"{name}_output"
    )(in_layer)

# heads
gender = build_head("gender", build_tower(neck))
image_quality = build_head("image_quality", build_tower(neck))
age = build_head("age", build_tower(neck))
weight = build_head("weight", build_tower(neck))
bag = build_head("bag", build_tower(neck))
footwear = build_head("footwear", build_tower(neck))
emotion = build_head("emotion", build_tower_emotion(neck))
pose = build_head("pose", build_tower(neck))


model = Model(
    inputs=backbone.input, 
    outputs=[gender, image_quality, age, weight, bag, footwear, pose, emotion]
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 45:
        lr *= 0.5e-3
    elif epoch > 35:
        lr *= 1e-3
    elif epoch > 25:
        lr *= 1e-2
    elif epoch > 15:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

    # lr = 0.5
    # if epoch > 45:
    #     lr *= 0.1
    # elif epoch > 40:
    #     lr *= 0.2
    # elif epoch > 30:
    #     lr *= 0.3
    # elif epoch > 20:
    #     lr *= 0.4
    # print('Learning rate: ', lr)
    # return lr

# %%
# losses = {
# 	"gender_output": "binary_crossentropy",
# 	"image_quality_output": "categorical_crossentropy",
# 	"age_output": "categorical_crossentropy",
# 	"weight_output": "categorical_crossentropy",

# }
# loss_weights = {"gender_output": 1.0, "image_quality_output": 1.0, "age_output": 1.0}
opt = SGD(lr=0.001, momentum=0.9)
model.compile(
    optimizer=opt,
    loss="categorical_crossentropy", 
    # loss_weights=loss_weights, 
    metrics=["accuracy"]
)

# %%
# model.fit(X_train, y_train, validation_data=(X_valid, y_valid), batch_size=32, epochs=10)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# block1_conv1 (Conv2D)           (None, 224, 224, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv2D)           (None, 224, 224, 64) 36928       block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling2D)      (None, 112, 112, 64) 0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv2D)           (None, 112, 112, 128 73856       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv2D)           (None, 112, 112, 128 147584      block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling2D)      (None, 56, 56, 128)  0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv2D)           (None, 56, 56, 256)  295168      block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv2D)           (None, 56, 56, 256)  590080      block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv3 (Conv2D)           (None, 56, 56, 256)  590080      block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling2D)      (None, 28, 28, 256)  0           block3_conv3[0][0]
# __________________________________________________________________________________________________
# block4_conv1 (Conv2D)           (None, 28, 28, 512)  1180160     block3_pool[0][0]
# __________________________________________________________________________________________________
# block4_conv2 (Conv2D)           (None, 28, 28, 512)  2359808     block4_conv1[0][0]
# __________________________________________________________________________________________________
# block4_conv3 (Conv2D)           (None, 28, 28, 512)  2359808     block4_conv2[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling2D)      (None, 14, 14, 512)  0           block4_conv3[0][0]
# __________________________________________________________________________________________________
# block5_conv1 (Conv2D)           (None, 14, 14, 512)  2359808     block4_pool[0][0]
# __________________________________________________________________________________________________
# block5_conv2 (Conv2D)           (None, 14, 14, 512)  2359808     block5_conv1[0][0]
# __________________________________________________________________________________________________
# block5_conv3 (Conv2D)           (None, 14, 14, 512)  2359808     block5_conv2[0][0]
# __________________________________________________________________________________________________
# block5_pool (MaxPooling2D)      (None, 7, 7, 512)    0           block5_conv3[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 25088)        0           block5_pool[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          12845568    flatten[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 128)          65664       dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 128)          65664       dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 128)          65664       dropout_5[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 128)          65664       dropout_7[0][0]
# __________________________________________________________________________________________________
# dense_10 (Dense)                (None, 128)          65664       dropout_9[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 128)          65664       dropout_11[0][0]
# __________________________________________________________________________________________________
# dense_16 (Dense)                (None, 128)          65664       dropout_15[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 256)          131328      dropout_13[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 128)          0           dense_2[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 128)          0           dense_4[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 128)          0           dense_6[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 128)          0           dense_8[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 128)          0           dense_10[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 128)          0           dense_12[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 128)          0           dense_16[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 256)          0           dense_14[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          16512       dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 128)          16512       dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 128)          16512       dropout_6[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 128)          16512       dropout_8[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 128)          16512       dropout_10[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 128)          16512       dropout_12[0][0]
# __________________________________________________________________________________________________
# dense_17 (Dense)                (None, 128)          16512       dropout_16[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 256)          65792       dropout_14[0][0]
# __________________________________________________________________________________________________
# gender_output (Dense)           (None, 2)            258         dense_3[0][0]
# __________________________________________________________________________________________________
# image_quality_output (Dense)    (None, 3)            387         dense_5[0][0]
# __________________________________________________________________________________________________
# age_output (Dense)              (None, 5)            645         dense_7[0][0]
# __________________________________________________________________________________________________
# weight_output (Dense)           (None, 4)            516         dense_9[0][0]
# __________________________________________________________________________________________________
# bag_output (Dense)              (None, 3)            387         dense_11[0][0]
# __________________________________________________________________________________________________
# footwear_output (Dense)         (None, 3)            387         dense_13[0][0]
# __________________________________________________________________________________________________
# pose_output (Dense)             (None, 3)            387         dense_17[0][0]
# __________________________________________________________________________________________________
# emotion_output (Dense)          (None, 4)            1028        dense_15[0][0]
# ==================================================================================================
# Total params: 28,336,603
# Trainable params: 28,336,603
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import os
import datetime
# Prepare model model saving directory.
# save_dir = os.path.join(os.getcwd(), 'saved_models')
t = datetime.datetime.today()
print(str(datetime.datetime.today()))
save_dir = "/content/gdrive/My Drive/EIP/Assignment5Dataset/saved_models"
model_name = 'A5_'+str(t)+'_model.{epoch:03d}.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)
filepath
# Out:
# 2019-12-27 04:30:51.515671
# '/content/gdrive/My Drive/EIP/Assignment5Dataset/saved_models/A5_2019-12-27 04:30:51.515601_model.{epoch:03d}.h5'

# %%
# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_loss',
                             verbose=1,
                             save_best_only=True)


es = EarlyStopping(monitor='val_loss', verbose=1, patience=5, mode='min')

lr_scheduler = LearningRateScheduler(lr_schedule, verbose=1)

# lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
#                                cooldown=0,
#                                patience=5,
#                                min_lr=0.5e-6)

# callbacks = [checkpoint, lr_reducer, lr_scheduler]
callbacks = [checkpoint,es,lr_scheduler]

# %%
model_output = model.fit_generator(
    generator=train_gen,
    validation_data=valid_gen,
    use_multiprocessing=True,
    workers=6, 
    epochs=50,
    verbose=1,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# Learning rate:  0.001
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.001.
# 360/360 [==============================] - 110s 306ms/step - loss: 5.4230 - gender_output_loss: 0.1830 - image_quality_output_loss: 0.8658 - age_output_loss: 1.2197 - weight_output_loss: 0.8223 - bag_output_loss: 0.6497 - footwear_output_loss: 0.5943 - pose_output_loss: 0.2607 - emotion_output_loss: 0.8274 - gender_output_acc: 0.9283 - image_quality_output_acc: 0.5911 - age_output_acc: 0.4603 - weight_output_acc: 0.6687 - bag_output_acc: 0.7345 - footwear_output_acc: 0.7409 - pose_output_acc: 0.9035 - emotion_output_acc: 0.7106 - val_loss: 7.1220 - val_gender_output_loss: 0.4966 - val_image_quality_output_loss: 0.9456 - val_age_output_loss: 1.4093 - val_weight_output_loss: 0.9537 - val_bag_output_loss: 0.8778 - val_footwear_output_loss: 0.8618 - val_pose_output_loss: 0.6694 - val_emotion_output_loss: 0.9077 - val_gender_output_acc: 0.8090 - val_image_quality_output_acc: 0.5585 - val_age_output_acc: 0.3952 - val_weight_output_acc: 0.6270 - val_bag_output_acc: 0.6326 - val_footwear_output_acc: 0.6043 - val_pose_output_acc: 0.7591 - val_emotion_output_acc: 0.7056
#
# Epoch 00001: val_loss improved from inf to 7.12199, saving model to /content/gdrive/My Drive/EIP/Assignment5Dataset/saved_models/A5_2019-12-27 04:30:51.515601_model.001.h5
# Epoch 2/50
# Learning rate:  0.001
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.001.
# 360/360 [==============================] - 105s 292ms/step - loss: 5.2289 - gender_output_loss: 0.1587 - image_quality_output_loss: 0.8436 - age_output_loss: 1.1908 - weight_output_loss: 0.7925 - bag_output_loss: 0.6236 - footwear_output_loss: 0.5699 - pose_output_loss: 0.2280 - emotion_output_loss: 0.8218 - gender_output_acc: 0.9391 - image_quality_output_acc: 0.6001 - age_output_acc: 0.4727 - weight_output_acc: 0.6786 - bag_output_acc: 0.7468 - footwear_output_acc: 0.7523 - pose_output_acc: 0.9157 - emotion_output_acc: 0.7125 - val_loss: 7.4961 - val_gender_output_loss: 0.5844 - val_image_quality_output_loss: 0.9676 - val_age_output_loss: 1.4370 - val_weight_output_loss: 0.9990 - val_bag_output_loss: 0.9406 - val_footwear_output_loss: 0.9004 - val_pose_output_loss: 0.7566 - val_emotion_output_loss: 0.9104 - val_gender_output_acc: 0.8130 - val_image_quality_output_acc: 0.5529 - val_age_output_acc: 0.3901 - val_weight_output_acc: 0.6144 - val_bag_output_acc: 0.6139 - val_footwear_output_acc: 0.6426 - val_pose_output_acc: 0.7762 - val_emotion_output_acc: 0.7046
#
# Epoch 00002: val_loss did not improve from 7.12199
# Epoch 3/50
# Learning rate:  0.001
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# 359/360 [============================>.] - ETA: 0s - loss: 4.9948 - gender_output_loss: 0.1523 - image_quality_output_loss: 0.8200 - age_output_loss: 1.1388 - weight_output_loss: 0.7519 - bag_output_loss: 0.5772 - footwear_output_loss: 0.5396 - pose_output_loss: 0.1995 - emotion_output_loss: 0.8154 - gender_output_acc: 0.9406 - image_quality_output_acc: 0.6102 - age_output_acc: 0.4960 - weight_output_acc: 0.6973 - bag_output_acc: 0.7700 - footwear_output_acc: 0.7677 - pose_output_acc: 0.9247 - emotion_output_acc: 0.7118
# Epoch 00003: LearningRateScheduler setting learning rate to 0.001.
# 360/360 [==============================] - 106s 294ms/step - loss: 4.9973 - gender_output_loss: 0.1524 - image_quality_output_loss: 0.8201 - age_output_loss: 1.1394 - weight_output_loss: 0.7531 - bag_output_loss: 0.5777 - footwear_output_loss: 0.5398 - pose_output_loss: 0.1996 - emotion_output_loss: 0.8153 - gender_output_acc: 0.9405 - image_quality_output_acc: 0.6102 - age_output_acc: 0.4964 - weight_output_acc: 0.6970 - bag_output_acc: 0.7697 - footwear_output_acc: 0.7676 - pose_output_acc: 0.9245 - emotion_output_acc: 0.7118 - val_loss: 7.4604 - val_gender_output_loss: 0.5373 - val_image_quality_output_loss: 0.9731 - val_age_output_loss: 1.4562 - val_weight_output_loss: 0.9961 - val_bag_output_loss: 0.9547 - val_footwear_output_loss: 0.9097 - val_pose_output_loss: 0.7312 - val_emotion_output_loss: 0.9021 - val_gender_output_acc: 0.8075 - val_image_quality_output_acc: 0.5635 - val_age_output_acc: 0.3800 - val_weight_output_acc: 0.6094 - val_bag_output_acc: 0.5988 - val_footwear_output_acc: 0.6265 - val_pose_output_acc: 0.7681 - val_emotion_output_acc: 0.7067
#
# Epoch 00003: val_loss did not improve from 7.12199
# Epoch 4/50
# Learning rate:  0.001
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.001.
# 360/360 [==============================] - 106s 294ms/step - loss: 4.7488 - gender_output_loss: 0.1368 - image_quality_output_loss: 0.7841 - age_output_loss: 1.0933 - weight_output_loss: 0.7118 - bag_output_loss: 0.5319 - footwear_output_loss: 0.5097 - pose_output_loss: 0.1798 - emotion_output_loss: 0.8014 - gender_output_acc: 0.9494 - image_quality_output_acc: 0.6322 - age_output_acc: 0.5105 - weight_output_acc: 0.7106 - bag_output_acc: 0.7879 - footwear_output_acc: 0.7831 - pose_output_acc: 0.9333 - emotion_output_acc: 0.7138 - val_loss: 7.7851 - val_gender_output_loss: 0.5381 - val_image_quality_output_loss: 0.9989 - val_age_output_loss: 1.4896 - val_weight_output_loss: 1.0603 - val_bag_output_loss: 1.0558 - val_footwear_output_loss: 0.9403 - val_pose_output_loss: 0.7900 - val_emotion_output_loss: 0.9121 - val_gender_output_acc: 0.8150 - val_image_quality_output_acc: 0.5378 - val_age_output_acc: 0.3826 - val_weight_output_acc: 0.5912 - val_bag_output_acc: 0.6129 - val_footwear_output_acc: 0.6290 - val_pose_output_acc: 0.7807 - val_emotion_output_acc: 0.7011
#
# Epoch 00004: val_loss did not improve from 7.12199
# Epoch 5/50
# Learning rate:  0.001
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.001.
# 359/360 [============================>.] - ETA: 0s - loss: 4.5034 - gender_output_loss: 0.1296 - image_quality_output_loss: 0.7572 - age_output_loss: 1.0395 - weight_output_loss: 0.6726 - bag_output_loss: 0.4875 - footwear_output_loss: 0.4684 - pose_output_loss: 0.1598 - emotion_output_loss: 0.7889 - gender_output_acc: 0.9493 - image_quality_output_acc: 0.6422 - age_output_acc: 0.5380 - weight_output_acc: 0.7273 - bag_output_acc: 0.8060 - footwear_output_acc: 0.7997 - pose_output_acc: 0.9417 - emotion_output_acc: 0.7170Epoch 5/50
# Learning rate:  0.001
# 360/360 [==============================] - 106s 294ms/step - loss: 4.5041 - gender_output_loss: 0.1296 - image_quality_output_loss: 0.7576 - age_output_loss: 1.0390 - weight_output_loss: 0.6727 - bag_output_loss: 0.4876 - footwear_output_loss: 0.4687 - pose_output_loss: 0.1597 - emotion_output_loss: 0.7893 - gender_output_acc: 0.9494 - image_quality_output_acc: 0.6421 - age_output_acc: 0.5384 - weight_output_acc: 0.7270 - bag_output_acc: 0.8057 - footwear_output_acc: 0.7998 - pose_output_acc: 0.9417 - emotion_output_acc: 0.7170 - val_loss: 8.3378 - val_gender_output_loss: 0.6401 - val_image_quality_output_loss: 1.0380 - val_age_output_loss: 1.5592 - val_weight_output_loss: 1.1243 - val_bag_output_loss: 1.0961 - val_footwear_output_loss: 1.0496 - val_pose_output_loss: 0.9071 - val_emotion_output_loss: 0.9235 - val_gender_output_acc: 0.8120 - val_image_quality_output_acc: 0.5444 - val_age_output_acc: 0.3674 - val_weight_output_acc: 0.6149 - val_bag_output_acc: 0.6023 - val_footwear_output_acc: 0.6210 - val_pose_output_acc: 0.7621 - val_emotion_output_acc: 0.7031
#
# Epoch 00005: val_loss did not improve from 7.12199
# Epoch 6/50
# Learning rate:  0.001
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.001.
# 359/360 [============================>.] - ETA: 0s - loss: 4.2300 - gender_output_loss: 0.1117 - image_quality_output_loss: 0.7049 - age_output_loss: 0.9825 - weight_output_loss: 0.6241 - bag_output_loss: 0.4432 - footwear_output_loss: 0.4421 - pose_output_loss: 0.1489 - emotion_output_loss: 0.7726 - gender_output_acc: 0.9574 - image_quality_output_acc: 0.6767 - age_output_acc: 0.5685 - weight_output_acc: 0.7430 - bag_output_acc: 0.8263 - footwear_output_acc: 0.8119 - pose_output_acc: 0.9450 - emotion_output_acc: 0.7176
# Epoch 00005: val_loss did not improve from 7.12199
# Epoch 6/50
# 360/360 [==============================] - 106s 293ms/step - loss: 4.2314 - gender_output_loss: 0.1116 - image_quality_output_loss: 0.7058 - age_output_loss: 0.9825 - weight_output_loss: 0.6242 - bag_output_loss: 0.4434 - footwear_output_loss: 0.4419 - pose_output_loss: 0.1492 - emotion_output_loss: 0.7728 - gender_output_acc: 0.9575 - image_quality_output_acc: 0.6760 - age_output_acc: 0.5683 - weight_output_acc: 0.7431 - bag_output_acc: 0.8260 - footwear_output_acc: 0.8122 - pose_output_acc: 0.9449 - emotion_output_acc: 0.7175 - val_loss: 8.2929 - val_gender_output_loss: 0.6027 - val_image_quality_output_loss: 1.0521 - val_age_output_loss: 1.5936 - val_weight_output_loss: 1.1082 - val_bag_output_loss: 1.1491 - val_footwear_output_loss: 1.0431 - val_pose_output_loss: 0.8206 - val_emotion_output_loss: 0.9235 - val_gender_output_acc: 0.8125 - val_image_quality_output_acc: 0.5312 - val_age_output_acc: 0.3614 - val_weight_output_acc: 0.5701 - val_bag_output_acc: 0.6179 - val_footwear_output_acc: 0.6255 - val_pose_output_acc: 0.7692 - val_emotion_output_acc: 0.7006
#
# Epoch 00006: val_loss did not improve from 7.12199
# Epoch 00006: early stopping

# %%
from keras.utils import plot_model
plot_model(model, to_file='/content/gdrive/My Drive/EIP/Assignment5Dataset/model.png')
