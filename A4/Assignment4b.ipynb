# %% [markdown]
# <a href="https://colab.research.google.com/github/csharpshooter/EIP/blob/master/A4/Assignment4b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!git clone https://github.com/yu4u/cutout-random-erasing.git


from __future__ import print_function
import keras
from keras.layers import Dense, Conv2D, BatchNormalization, Activation
from keras.layers import AveragePooling2D, Input, Flatten
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, LearningRateScheduler
from keras.callbacks import ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator
from keras.regularizers import l2
from keras import backend as K
from keras.models import Model
from keras.datasets import cifar10
import numpy as np
import os
import matplotlib.pyplot as plt
import numpy as np

# %%
# Training parameters
batch_size = 128  # orig paper trained all networks with batch_size=128
epochs = 50
data_augmentation = True
num_classes = 10
random_erasing = True
pixel_level = False

# %%
# Subtracting pixel mean improves accuracy
subtract_pixel_mean = True

# %%
# Model parameter
# ----------------------------------------------------------------------------
#           |      | 200-epoch | Orig Paper| 200-epoch | Orig Paper| sec/epoch
# Model     |  n   | ResNet v1 | ResNet v1 | ResNet v2 | ResNet v2 | GTX1080Ti
#           |v1(v2)| %Accuracy | %Accuracy | %Accuracy | %Accuracy | v1 (v2)
# ----------------------------------------------------------------------------
# ResNet20  | 3 (2)| 92.16     | 91.25     | -----     | -----     | 35 (---)
# ResNet32  | 5(NA)| 92.46     | 92.49     | NA        | NA        | 50 ( NA)
# ResNet44  | 7(NA)| 92.50     | 92.83     | NA        | NA        | 70 ( NA)
# ResNet56  | 9 (6)| 92.71     | 93.03     | 93.01     | NA        | 90 (100)
# ResNet110 |18(12)| 92.65     | 93.39+-.16| 93.15     | 93.63     | 165(180)
# ResNet164 |27(18)| -----     | 94.07     | -----     | 94.54     | ---(---)
# ResNet1001| (111)| -----     | 92.39     | -----     | 95.08+-.14| ---(---)
# ---------------------------------------------------------------------------
n = 3

# %%
# Model version
# Orig paper: version = 1 (ResNet v1), Improved ResNet: version = 2 (ResNet v2)
version = 1

# %%
# Computed depth from supplied model parameter n
if version == 1:
    depth = n * 6 + 2
elif version == 2:
    depth = n * 9 + 2

# %%
# Model name, depth and version
model_type = 'ResNet%dv%d' % (depth, version)

# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Input image dimensions.
input_shape = x_train.shape[1:]

# Normalize data.
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# %%
# If subtract pixel mean is enabled
if subtract_pixel_mean:
    x_train_mean = np.mean(x_train, axis=0)
    x_train -= x_train_mean
    x_test -= x_train_mean

print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)

# %%
# Convert class vectors to binary class matrices.
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
def get_random_eraser(p=0.5, s_l=0.02, s_h=0.4, r_1=0.3, r_2=1/0.3, v_l=0, v_h=255, pixel_level=False):
    def eraser(input_img):
        img_h, img_w, img_c = input_img.shape
        p_1 = np.random.rand()

        if p_1 > p:
            return input_img

        while True:
            s = np.random.uniform(s_l, s_h) * img_h * img_w
            r = np.random.uniform(r_1, r_2)
            w = int(np.sqrt(s / r))
            h = int(np.sqrt(s * r))
            left = np.random.randint(0, img_w)
            top = np.random.randint(0, img_h)

            if left + w <= img_w and top + h <= img_h:
                break

        if pixel_level:
            c = np.random.uniform(v_l, v_h, (h, w, img_c))
        else:
            c = np.random.uniform(v_l, v_h)

        input_img[top:top + h, left:left + w, :] = c

        return input_img

    return eraser

# %%
def lr_schedule(epoch):
    """Learning Rate Schedule

    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.

    # Arguments
        epoch (int): The number of epochs

    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
#    if epoch > 45:
#        lr *= 0.5e-3
#    elif epoch > 40:
#        lr *= 1e-3
#    elif epoch > 0:
    if epoch > 40:
        lr *= 1e-2
    elif epoch > 30:
#    if epoch > 20:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr

# %%
def resnet_layer(inputs,
                 num_filters=16,
                 kernel_size=3,
                 strides=1,
                 activation='relu',
                 batch_normalization=True,
                 conv_first=True):
    """2D Convolution-Batch Normalization-Activation stack builder

    # Arguments
        inputs (tensor): input tensor from input image or previous layer
        num_filters (int): Conv2D number of filters
        kernel_size (int): Conv2D square kernel dimensions
        strides (int): Conv2D square stride dimensions
        activation (string): activation name
        batch_normalization (bool): whether to include batch normalization
        conv_first (bool): conv-bn-activation (True) or
            bn-activation-conv (False)

    # Returns
        x (tensor): tensor as input to the next layer
    """
    conv = Conv2D(num_filters,
                  kernel_size=kernel_size,
                  strides=strides,
                  padding='same',
                  kernel_initializer='he_normal',
                  kernel_regularizer=l2(1e-4))

    x = inputs
    if conv_first:
        x = conv(x)
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
    else:
        if batch_normalization:
            x = BatchNormalization()(x)
        if activation is not None:
            x = Activation(activation)(x)
        x = conv(x)
    return x

# %%
def resnet_v1(input_shape, depth, num_classes=10):
    """ResNet Version 1 Model builder [a]

    Stacks of 2 x (3 x 3) Conv2D-BN-ReLU
    Last ReLU is after the shortcut connection.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filters is
    doubled. Within each stage, the layers have the same number filters and the
    same number of filters.
    Features maps sizes:
    stage 0: 32x32, 16
    stage 1: 16x16, 32
    stage 2:  8x8,  64
    The Number of parameters is approx the same as Table 6 of [a]:
    ResNet20 0.27M
    ResNet32 0.46M
    ResNet44 0.66M
    ResNet56 0.85M
    ResNet110 1.7M

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 6 != 0:
        raise ValueError('depth should be 6n+2 (eg 20, 32, 44 in [a])')
    # Start model definition.
    num_filters = 16
    num_res_blocks = int((depth - 2) / 6)

    inputs = Input(shape=input_shape)
    x = resnet_layer(inputs=inputs)
    # Instantiate the stack of residual units
    for stack in range(3):
        for res_block in range(num_res_blocks):
            strides = 1
            if stack > 0 and res_block == 0:  # first layer but not first stack
                strides = 2  # downsample
            y = resnet_layer(inputs=x,
                             num_filters=num_filters,
                             strides=strides)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters,
                             activation=None)
            if stack > 0 and res_block == 0:  # first layer but not first stack
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])
            x = Activation('relu')(x)
        num_filters *= 2

    # Add classifier on top.
    # v1 does not use BN after last shortcut connection-ReLU
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
def resnet_v2(input_shape, depth, num_classes=10):
    """ResNet Version 2 Model builder [b]

    Stacks of (1 x 1)-(3 x 3)-(1 x 1) BN-ReLU-Conv2D or also known as
    bottleneck layer
    First shortcut connection per layer is 1 x 1 Conv2D.
    Second and onwards shortcut connection is identity.
    At the beginning of each stage, the feature map size is halved (downsampled)
    by a convolutional layer with strides=2, while the number of filter maps is
    doubled. Within each stage, the layers have the same number filters and the
    same filter map sizes.
    Features maps sizes:
    conv1  : 32x32,  16
    stage 0: 32x32,  64
    stage 1: 16x16, 128
    stage 2:  8x8,  256

    # Arguments
        input_shape (tensor): shape of input image tensor
        depth (int): number of core convolutional layers
        num_classes (int): number of classes (CIFAR10 has 10)

    # Returns
        model (Model): Keras model instance
    """
    if (depth - 2) % 9 != 0:
        raise ValueError('depth should be 9n+2 (eg 56 or 110 in [b])')
    # Start model definition.
    num_filters_in = 16
    num_res_blocks = int((depth - 2) / 9)

    inputs = Input(shape=input_shape)
    # v2 performs Conv2D with BN-ReLU on input before splitting into 2 paths
    x = resnet_layer(inputs=inputs,
                     num_filters=num_filters_in,
                     conv_first=True)

    # Instantiate the stack of residual units
    for stage in range(3):
        for res_block in range(num_res_blocks):
            activation = 'relu'
            batch_normalization = True
            strides = 1
            if stage == 0:
                num_filters_out = num_filters_in * 4
                if res_block == 0:  # first layer and first stage
                    activation = None
                    batch_normalization = False
            else:
                num_filters_out = num_filters_in * 2
                if res_block == 0:  # first layer but not first stage
                    strides = 2    # downsample

            # bottleneck residual unit
            y = resnet_layer(inputs=x,
                             num_filters=num_filters_in,
                             kernel_size=1,
                             strides=strides,
                             activation=activation,
                             batch_normalization=batch_normalization,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_in,
                             conv_first=False)
            y = resnet_layer(inputs=y,
                             num_filters=num_filters_out,
                             kernel_size=1,
                             conv_first=False)
            if res_block == 0:
                # linear projection residual shortcut connection to match
                # changed dims
                x = resnet_layer(inputs=x,
                                 num_filters=num_filters_out,
                                 kernel_size=1,
                                 strides=strides,
                                 activation=None,
                                 batch_normalization=False)
            x = keras.layers.add([x, y])

        num_filters_in = num_filters_out

    # Add classifier on top.
    # v2 has BN-ReLU before Pooling
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = AveragePooling2D(pool_size=8)(x)
    y = Flatten()(x)
    outputs = Dense(num_classes,
                    activation='softmax',
                    kernel_initializer='he_normal')(y)

    # Instantiate model.
    model = Model(inputs=inputs, outputs=outputs)
    return model

# %%
if version == 2:
    model = resnet_v2(input_shape=input_shape, depth=depth)
else:
    model = resnet_v1(input_shape=input_shape, depth=depth)

model.compile(loss='categorical_crossentropy',
              optimizer=Adam(lr=lr_schedule(0)),
              metrics=['accuracy'])
# Out:
# Learning rate:  0.001

# %%
model.summary()
print(model_type)
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 32, 32, 16)   448         input_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 32, 32, 16)   64          conv2d_74[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 32, 32, 16)   0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 32, 32, 16)   2320        activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 32, 32, 16)   64          conv2d_75[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 32, 32, 16)   0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 32, 32, 16)   2320        activation_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 32, 32, 16)   64          conv2d_76[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 32, 32, 16)   0           activation_67[0][0]
#                                                                  batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 32, 32, 16)   0           add_28[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 32, 32, 16)   2320        activation_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 32, 32, 16)   64          conv2d_77[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 32, 32, 16)   0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 32, 32, 16)   2320        activation_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 32, 32, 16)   64          conv2d_78[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 32, 32, 16)   0           activation_69[0][0]
#                                                                  batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 32, 32, 16)   0           add_29[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 32, 32, 16)   2320        activation_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 32, 32, 16)   64          conv2d_79[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 32, 32, 16)   0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 32, 32, 16)   2320        activation_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 32, 32, 16)   64          conv2d_80[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 32, 32, 16)   0           activation_71[0][0]
#                                                                  batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 32, 32, 16)   0           add_30[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 16, 16, 32)   4640        activation_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 16, 16, 32)   128         conv2d_81[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 16, 16, 32)   0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 16, 16, 32)   9248        activation_74[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 16, 16, 32)   544         activation_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 16, 16, 32)   128         conv2d_82[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 16, 16, 32)   0           conv2d_83[0][0]
#                                                                  batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 16, 16, 32)   0           add_31[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 16, 16, 32)   9248        activation_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 16, 16, 32)   128         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 16, 16, 32)   0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 16, 16, 32)   9248        activation_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 16, 16, 32)   128         conv2d_85[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 16, 16, 32)   0           activation_75[0][0]
#                                                                  batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 16, 16, 32)   0           add_32[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 16, 16, 32)   9248        activation_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 16, 16, 32)   128         conv2d_86[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 16, 16, 32)   0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 16, 16, 32)   9248        activation_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 16, 16, 32)   128         conv2d_87[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 16, 16, 32)   0           activation_77[0][0]
#                                                                  batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 16, 16, 32)   0           add_33[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 8, 8, 64)     18496       activation_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 8, 8, 64)     256         conv2d_88[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 8, 8, 64)     0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 8, 8, 64)     36928       activation_80[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 8, 8, 64)     2112        activation_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 8, 8, 64)     256         conv2d_89[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 8, 8, 64)     0           conv2d_90[0][0]
#                                                                  batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 8, 8, 64)     0           add_34[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 8, 8, 64)     36928       activation_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 8, 8, 64)     256         conv2d_91[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 8, 8, 64)     0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 8, 8, 64)     36928       activation_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 8, 8, 64)     256         conv2d_92[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 8, 8, 64)     0           activation_81[0][0]
#                                                                  batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 8, 8, 64)     0           add_35[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 8, 8, 64)     36928       activation_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 8, 8, 64)     256         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 8, 8, 64)     0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 8, 8, 64)     36928       activation_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 8, 8, 64)     256         conv2d_94[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 8, 8, 64)     0           activation_83[0][0]
#                                                                  batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 8, 8, 64)     0           add_36[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 1, 1, 64)     0           activation_85[0][0]
# __________________________________________________________________________________________________
# flatten_4 (Flatten)             (None, 64)           0           average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 10)           650         flatten_4[0][0]
# ==================================================================================================
# Total params: 274,442
# Trainable params: 273,066
# Non-trainable params: 1,376
# __________________________________________________________________________________________________
# ResNet20v1

# %%
# Prepare model model saving directory.
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_%s_model.{epoch:03d}.h5' % model_type
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# %%
# Prepare callbacks for model saving and for learning rate adjustment.
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# %%
# Run training, with or without data augmentation.
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # This will do preprocessing and realtime data augmentation:
    datagen = ImageDataGenerator(
        # set input mean to 0 over the dataset
        featurewise_center=False,
        # set each sample mean to 0
        samplewise_center=False,
        # divide inputs by std of dataset
        featurewise_std_normalization=False,
        # divide each input by its std
        samplewise_std_normalization=False,
        # apply ZCA whitening
        zca_whitening=False,
        # epsilon for ZCA whitening
        zca_epsilon=1e-06,
        # randomly rotate images in the range (deg 0 to 180)
        rotation_range=0,
        # randomly shift images horizontally
        width_shift_range=0.1,
        # randomly shift images vertically
        height_shift_range=0.1,
        # set range for random shear
        shear_range=0.,
        # set range for random zoom
        zoom_range=0.,
        # set range for random channel shifts
        channel_shift_range=0.,
        # set mode for filling points outside the input boundaries
        fill_mode='nearest',
        # value used for fill_mode = "constant"
        cval=0.,
        # randomly flip images
        horizontal_flip=True,
        # randomly flip images
        vertical_flip=False,
        # set rescaling factor (applied before any other transformation)
        rescale=None,
        # set function that will be applied on each input
        preprocessing_function=get_random_eraser(v_l=0, v_h=1, pixel_level=pixel_level),
        # image data format, either "channels_first" or "channels_last"
        data_format=None,
        # fraction of images reserved for validation (strictly between 0 and 1)
        validation_split=0.0)
# Out:
# Using real-time data augmentation.

# %%
    # Compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied).
    datagen.fit(x_train)

# %%
    # Fit the model on the batches generated by datagen.flow().
    model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
                        validation_data=(x_test, y_test),
                        epochs=epochs, verbose=1, workers=4,
                        callbacks=callbacks)
# Out:
# Epoch 1/50
# Learning rate:  0.001
# 391/391 [==============================] - 70s 178ms/step - loss: 1.7570 - acc: 0.4168 - val_loss: 2.4104 - val_acc: 0.3219
#
# Epoch 00001: val_acc improved from -inf to 0.32190, saving model to /content/saved_models/cifar10_ResNet20v1_model.001.h5
# Epoch 2/50
# Learning rate:  0.001
# 391/391 [==============================] - 56s 144ms/step - loss: 1.4147 - acc: 0.5436 - val_loss: 1.4989 - val_acc: 0.5386
#
# Epoch 00002: val_acc improved from 0.32190 to 0.53860, saving model to /content/saved_models/cifar10_ResNet20v1_model.002.h5
# Epoch 3/50
# Learning rate:  0.001
# 391/391 [==============================] - 57s 145ms/step - loss: 1.2454 - acc: 0.6053 - val_loss: 1.4427 - val_acc: 0.5771
#
# Epoch 00003: val_acc improved from 0.53860 to 0.57710, saving model to /content/saved_models/cifar10_ResNet20v1_model.003.h5
# Epoch 4/50
# Learning rate:  0.001
# 391/391 [==============================] - 57s 146ms/step - loss: 1.1324 - acc: 0.6520 - val_loss: 1.4061 - val_acc: 0.6289
#
# Epoch 00004: val_acc improved from 0.57710 to 0.62890, saving model to /content/saved_models/cifar10_ResNet20v1_model.004.h5
# Epoch 5/50
# Learning rate:  0.001
# 391/391 [==============================] - 57s 146ms/step - loss: 1.0423 - acc: 0.6839 - val_loss: 1.3241 - val_acc: 0.6349
#
# Epoch 00005: val_acc improved from 0.62890 to 0.63490, saving model to /content/saved_models/cifar10_ResNet20v1_model.005.h5
# Epoch 6/50
# Learning rate:  0.001
# 391/391 [==============================] - 57s 145ms/step - loss: 0.9809 - acc: 0.7058 - val_loss: 1.0861 - val_acc: 0.6805
#
# Epoch 00006: val_acc improved from 0.63490 to 0.68050, saving model to /content/saved_models/cifar10_ResNet20v1_model.006.h5
# Epoch 7/50
# Learning rate:  0.001
# 391/391 [==============================] - 56s 144ms/step - loss: 0.9363 - acc: 0.7225 - val_loss: 1.1914 - val_acc: 0.6593
#
# Epoch 00007: val_acc did not improve from 0.68050
# Epoch 8/50
# Learning rate:  0.001
# 391/391 [==============================] - 56s 144ms/step - loss: 0.8967 - acc: 0.7371 - val_loss: 0.9764 - val_acc: 0.7165
#
# Epoch 00008: val_acc improved from 0.68050 to 0.71650, saving model to /content/saved_models/cifar10_ResNet20v1_model.008.h5
# Epoch 9/50
# Learning rate:  0.001
# 391/391 [==============================] - 56s 144ms/step - loss: 0.8623 - acc: 0.7468 - val_loss: 1.0306 - val_acc: 0.7152
#
# Epoch 00009: val_acc did not improve from 0.71650
# Epoch 10/50
# Learning rate:  0.001
# 391/391 [==============================] - 57s 145ms/step - loss: 0.8309 - acc: 0.7574 - val_loss: 1.2426 - val_acc: 0.6719
#
# Epoch 00010: val_acc did not improve from 0.71650
# Epoch 11/50
# Learning rate:  0.001
# 391/391 [==============================] - 56s 143ms/step - loss: 0.8092 - acc: 0.7667 - val_loss: 1.1730 - val_acc: 0.6817
#
# Epoch 00011: val_acc did not improve from 0.71650
# Epoch 12/50
# Learning rate:  0.001
# 391/391 [==============================] - 56s 144ms/step - loss: 0.7826 - acc: 0.7778 - val_loss: 0.8607 - val_acc: 0.7589
#
# Epoch 00012: val_acc improved from 0.71650 to 0.75890, saving model to /content/saved_models/cifar10_ResNet20v1_model.012.h5
# Epoch 13/50
# Learning rate:  0.001
# 391/391 [==============================] - 57s 145ms/step - loss: 0.7629 - acc: 0.7839 - val_loss: 0.7970 - val_acc: 0.7762
#
# Epoch 00013: val_acc improved from 0.75890 to 0.77620, saving model to /content/saved_models/cifar10_ResNet20v1_model.013.h5
# Epoch 14/50
# Learning rate:  0.001
# 391/391 [==============================] - 57s 146ms/step - loss: 0.7396 - acc: 0.7925 - val_loss: 0.9077 - val_acc: 0.7473
#
# Epoch 00014: val_acc did not improve from 0.77620
# Epoch 15/50
# Learning rate:  0.001
# 391/391 [==============================] - 57s 146ms/step - loss: 0.7236 - acc: 0.7981 - val_loss: 0.8262 - val_acc: 0.7699
#
# Epoch 00015: val_acc did not improve from 0.77620
# Epoch 16/50
# Learning rate:  0.001
# 391/391 [==============================] - 57s 147ms/step - loss: 0.7087 - acc: 0.8032 - val_loss: 0.8109 - val_acc: 0.7807
#
# Epoch 00016: val_acc improved from 0.77620 to 0.78070, saving model to /content/saved_models/cifar10_ResNet20v1_model.016.h5
# Epoch 17/50
# Learning rate:  0.001
# 391/391 [==============================] - 57s 145ms/step - loss: 0.6957 - acc: 0.8065 - val_loss: 1.0327 - val_acc: 0.7180
#
# Epoch 00017: val_acc did not improve from 0.78070
# Epoch 18/50
# Learning rate:  0.001
# 391/391 [==============================] - 57s 146ms/step - loss: 0.6860 - acc: 0.8108 - val_loss: 0.8663 - val_acc: 0.7716
#
# Epoch 00018: val_acc did not improve from 0.78070
# Epoch 19/50
# Learning rate:  0.001
# 391/391 [==============================] - 57s 145ms/step - loss: 0.6686 - acc: 0.8178 - val_loss: 0.8544 - val_acc: 0.7727
#
# Epoch 00019: val_acc did not improve from 0.78070
# Epoch 20/50
# Learning rate:  0.001
# 391/391 [==============================] - 57s 146ms/step - loss: 0.6595 - acc: 0.8215 - val_loss: 0.7162 - val_acc: 0.8143
#
# Epoch 00020: val_acc improved from 0.78070 to 0.81430, saving model to /content/saved_models/cifar10_ResNet20v1_model.020.h5
# Epoch 21/50
# Learning rate:  0.001
# 391/391 [==============================] - 56s 143ms/step - loss: 0.6468 - acc: 0.8259 - val_loss: 0.9210 - val_acc: 0.7581
#
# Epoch 00021: val_acc did not improve from 0.81430
# Epoch 22/50
# Learning rate:  0.001
# 391/391 [==============================] - 57s 145ms/step - loss: 0.6402 - acc: 0.8275 - val_loss: 0.7386 - val_acc: 0.8073
#
# Epoch 00022: val_acc did not improve from 0.81430
# Epoch 23/50
# Learning rate:  0.001
# 391/391 [==============================] - 56s 143ms/step - loss: 0.6307 - acc: 0.8308 - val_loss: 0.7286 - val_acc: 0.8040
#
# Epoch 00023: val_acc did not improve from 0.81430
# Epoch 24/50
# Learning rate:  0.001
# 391/391 [==============================] - 56s 144ms/step - loss: 0.6226 - acc: 0.8345 - val_loss: 0.7685 - val_acc: 0.7996
#
# Epoch 00024: val_acc did not improve from 0.81430
# Epoch 25/50
# Learning rate:  0.001
# 391/391 [==============================] - 56s 144ms/step - loss: 0.6146 - acc: 0.8366 - val_loss: 0.8642 - val_acc: 0.7744
#
# Epoch 00025: val_acc did not improve from 0.81430
# Epoch 26/50
# Learning rate:  0.001
# 391/391 [==============================] - 56s 144ms/step - loss: 0.6134 - acc: 0.8392 - val_loss: 0.9026 - val_acc: 0.7579
#
# Epoch 00026: val_acc did not improve from 0.81430
# Epoch 27/50
# Learning rate:  0.001
# 391/391 [==============================] - 57s 145ms/step - loss: 0.6042 - acc: 0.8409 - val_loss: 0.8338 - val_acc: 0.7871
#
# Epoch 00027: val_acc did not improve from 0.81430
# Epoch 28/50
# Learning rate:  0.001
# 391/391 [==============================] - 56s 144ms/step - loss: 0.5966 - acc: 0.8437 - val_loss: 0.6837 - val_acc: 0.8175
#
# Epoch 00028: val_acc improved from 0.81430 to 0.81750, saving model to /content/saved_models/cifar10_ResNet20v1_model.028.h5
# Epoch 29/50
# Learning rate:  0.001
# 391/391 [==============================] - 56s 142ms/step - loss: 0.5902 - acc: 0.8469 - val_loss: 0.7174 - val_acc: 0.8098
#
# Epoch 00029: val_acc did not improve from 0.81750
# Epoch 30/50
# Learning rate:  0.001
# 391/391 [==============================] - 56s 144ms/step - loss: 0.5831 - acc: 0.8478 - val_loss: 0.9098 - val_acc: 0.7588
#
# Epoch 00030: val_acc did not improve from 0.81750
# Epoch 31/50
# Learning rate:  0.001
# 391/391 [==============================] - 56s 143ms/step - loss: 0.5805 - acc: 0.8480 - val_loss: 0.6539 - val_acc: 0.8313
#
# Epoch 00031: val_acc improved from 0.81750 to 0.83130, saving model to /content/saved_models/cifar10_ResNet20v1_model.031.h5
# Epoch 32/50
# Learning rate:  0.001
# 391/391 [==============================] - 56s 143ms/step - loss: 0.5786 - acc: 0.8508 - val_loss: 0.7903 - val_acc: 0.7970
#
# Epoch 00032: val_acc did not improve from 0.83130
# Epoch 33/50
# Learning rate:  0.001
# 391/391 [==============================] - 56s 143ms/step - loss: 0.5663 - acc: 0.8546 - val_loss: 0.6951 - val_acc: 0.8257
#
# Epoch 00033: val_acc did not improve from 0.83130
# Epoch 34/50
# Learning rate:  0.001
# 391/391 [==============================] - 56s 143ms/step - loss: 0.5670 - acc: 0.8565 - val_loss: 1.0437 - val_acc: 0.7557
#
# Epoch 00034: val_acc did not improve from 0.83130
# Epoch 35/50
# Learning rate:  0.001
# 391/391 [==============================] - 56s 142ms/step - loss: 0.5572 - acc: 0.8596 - val_loss: 0.7272 - val_acc: 0.8115
#
# Epoch 00035: val_acc did not improve from 0.83130
# Epoch 36/50
# Learning rate:  0.001
# 391/391 [==============================] - 56s 142ms/step - loss: 0.5555 - acc: 0.8586 - val_loss: 0.7099 - val_acc: 0.8195
#
# Epoch 00036: val_acc did not improve from 0.83130
# Epoch 37/50
# Learning rate:  0.0001
# 391/391 [==============================] - 56s 144ms/step - loss: 0.4830 - acc: 0.8857 - val_loss: 0.5017 - val_acc: 0.8782
#
# Epoch 00037: val_acc improved from 0.83130 to 0.87820, saving model to /content/saved_models/cifar10_ResNet20v1_model.037.h5
# Epoch 38/50
# Learning rate:  0.0001
# 391/391 [==============================] - 56s 143ms/step - loss: 0.4585 - acc: 0.8929 - val_loss: 0.5013 - val_acc: 0.8787
#
# Epoch 00038: val_acc improved from 0.87820 to 0.87870, saving model to /content/saved_models/cifar10_ResNet20v1_model.038.h5
# Epoch 39/50
# Learning rate:  0.0001
# 391/391 [==============================] - 56s 142ms/step - loss: 0.4457 - acc: 0.8964 - val_loss: 0.4968 - val_acc: 0.8806
#
# Epoch 00039: val_acc improved from 0.87870 to 0.88060, saving model to /content/saved_models/cifar10_ResNet20v1_model.039.h5
# Epoch 40/50
# Learning rate:  0.0001
# 391/391 [==============================] - 55s 142ms/step - loss: 0.4407 - acc: 0.8988 - val_loss: 0.4922 - val_acc: 0.8832
#
# Epoch 00040: val_acc improved from 0.88060 to 0.88320, saving model to /content/saved_models/cifar10_ResNet20v1_model.040.h5
# Epoch 41/50
# Learning rate:  0.0001
# 391/391 [==============================] - 55s 141ms/step - loss: 0.4314 - acc: 0.9007 - val_loss: 0.5043 - val_acc: 0.8769
#
# Epoch 00041: val_acc did not improve from 0.88320
# Epoch 42/50
# Learning rate:  0.0001
# 391/391 [==============================] - 56s 142ms/step - loss: 0.4271 - acc: 0.9019 - val_loss: 0.5150 - val_acc: 0.8785
#
# Epoch 00042: val_acc did not improve from 0.88320
# Epoch 43/50
# Learning rate:  0.0001
# 391/391 [==============================] - 56s 142ms/step - loss: 0.4230 - acc: 0.9039 - val_loss: 0.4853 - val_acc: 0.8859
#
# Epoch 00043: val_acc improved from 0.88320 to 0.88590, saving model to /content/saved_models/cifar10_ResNet20v1_model.043.h5
# Epoch 44/50
# Learning rate:  0.0001
# 391/391 [==============================] - 56s 143ms/step - loss: 0.4199 - acc: 0.9028 - val_loss: 0.4900 - val_acc: 0.8839
#
# Epoch 00044: val_acc did not improve from 0.88590
# Epoch 45/50
# Learning rate:  0.0001
# 391/391 [==============================] - 55s 141ms/step - loss: 0.4163 - acc: 0.9033 - val_loss: 0.4881 - val_acc: 0.8833
#
# Epoch 00045: val_acc did not improve from 0.88590
# Epoch 46/50
# Learning rate:  0.0001
# 391/391 [==============================] - 56s 142ms/step - loss: 0.4079 - acc: 0.9076 - val_loss: 0.4836 - val_acc: 0.8870
#
# Epoch 00046: val_acc improved from 0.88590 to 0.88700, saving model to /content/saved_models/cifar10_ResNet20v1_model.046.h5
# Epoch 47/50
# Learning rate:  0.0001
# 391/391 [==============================] - 56s 142ms/step - loss: 0.4065 - acc: 0.9084 - val_loss: 0.4882 - val_acc: 0.8842
#
# Epoch 00047: val_acc did not improve from 0.88700
# Epoch 48/50
# Learning rate:  0.0001
# 391/391 [==============================] - 56s 143ms/step - loss: 0.4012 - acc: 0.9084 - val_loss: 0.4936 - val_acc: 0.8835
#
# Epoch 00048: val_acc did not improve from 0.88700
# Epoch 49/50
# Learning rate:  0.0001
# 391/391 [==============================] - 56s 142ms/step - loss: 0.3993 - acc: 0.9092 - val_loss: 0.4994 - val_acc: 0.8834
#
# Epoch 00049: val_acc did not improve from 0.88700
# Epoch 50/50
# Learning rate:  0.0001
# 391/391 [==============================] - 56s 142ms/step - loss: 0.3993 - acc: 0.9091 - val_loss: 0.4847 - val_acc: 0.8852
#
# Epoch 00050: val_acc did not improve from 0.88700

# %%
# Score trained model.
scores = model.evaluate(x_test, y_test, verbose=1)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# 10000/10000 [==============================] - 4s 384us/step
# Test loss: 0.4846624554634094
# Test accuracy: 0.8852
